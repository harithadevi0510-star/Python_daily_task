# %% [markdown]
# # 1

# %%
import copy
original=[1,2,[3,4],5]
copy=copy.copy(original)
copy[2][0]=99
print(original)
print(copy)
# Out:
# [1, 2, [99, 4], 5]
# [1, 2, [99, 4], 5]

# %% [markdown]
# # 2

# %%
import copy
original=[1,2,[3,4],5]
copy=copy.deepcopy(original)
copy[2][0]=99
print(original)
print(copy)
# Out:
# [1, 2, [3, 4], 5]
# [1, 2, [99, 4], 5]

# %% [markdown]
# # 3

# %%
lists1=[[1,2,3],[4,5,6]]
lists2=copy.copy()
print(lists1)
print(lists2)
# Out:
# [[1, 2, 3], [4, 5, 6]]
# [1, 2, [99, 4], 5]

# %% [markdown]
# # 4

# %%
import copy
list1=[[1,2,3],[4,5,6]]
list2=copy.deepcopy(list1)
print(list1)
print(list2)
# Out:
# [[1, 2, 3], [4, 5, 6]]
# [[1, 2, 3], [4, 5, 6]]

# %% [markdown]
# # 5

# %%
import copy
original={"name":"hari","marks":{"math":45, "Eng":50}}
copy=copy.copy(original)
copy["marks"]["math"]=60
print(original)
print(copy)
# Out:
# {'name': 'hari', 'marks': {'math': 60, 'Eng': 50}}
# {'name': 'hari', 'marks': {'math': 60, 'Eng': 50}}

# %% [markdown]
# # 6

# %%
import copy
class person:
    def __init__(self, name, hobbies):
        self.name=name
        self.hobbies=hobbies
person1=person("hari",["reading","watching tv"])
person2=copy.copy(person1)
person2.hobbies.append("eating")
print(person1.hobbies)
print(person2.hobbies)
# Out:
# ['reading', 'watching tv', 'eating']
# ['reading', 'watching tv', 'eating']

# %% [markdown]
# # 7

# %%
import copy
def manual_deep_copy(lst):
    if isinstance(lst,list):
        return [manual_deep_copy(item) for item in lst]
    else:
        return lst
        
# original list:
original_list = [1,2,[3,4],[5,[6,7,8]]]

#calling the function
deep_copy_list=manual_deep_copy(original_list)

# modify the deep copy list
deep_copy_list[3][1][0] = 50

print("Original List",original_list)
print("Copy List",deep_copy_list)
# Out:
# Original List [1, 2, [3, 4], [5, [6, 7, 8]]]
# Copy List [1, 2, [3, 4], [5, [50, 7, 8]]]

# %%
import copy
def manual_create_deep(lst):
    if isinstance(lst,list):
        return [manual_create_deep(item) for item in lst]
    else:
        return lst
        
# original list:
original_list = [1,2,[3,4],[5,[6,7,8]]]

#calling the function
deep_copy_list=manual_create_deep(original_list)

# modify the deep copy list
deep_copy_list[3][1][0] = 50

print("Original List",original_list)
print("Copy List",deep_copy_list)
# Out:
# Original List [1, 2, [3, 4], [5, [6, 7, 8]]]
# Copy List [1, 2, [3, 4], [5, [50, 7, 8]]]

# %% [markdown]
# # 8

# %%
import copy
data = [10, [20, 30], {"name": "Hari"}, 40]
shallow = copy.copy(data)
deep = copy.deepcopy(data)
data[1][0] = 80
data[2]["name"] = "Unnu"
print("Original:", data)
print("Shallow :", shallow)
print("Deep    :", deep)
# Out:
# Original: [10, [80, 30], {'name': 'Unnu'}, 40]
# Shallow : [10, [80, 30], {'name': 'Unnu'}, 40]
# Deep    : [10, [20, 30], {'name': 'Hari'}, 40]

# %% [markdown]
# # 9

# %%
def detect_copy(original):
    # create the shallow copy
    shallow_copy = copy.copy(original)
     # create the deep copy
    deep_copy = copy.deepcopy(original)
     # modify the shallow copy
    shallow_copy[2][1] = 100
     # modify the deep copy
    deep_copy[1][0] = 300
    if shallow_copy == original:
        return f"Shallow Copy : {shallow_copy}"
    if deep_copy == original:
        return f"Deep Copy : {deep_copy}"
original = [[1,2],[3,4],[5,6]]
detect_copy(original)
# Out:
# 'Shallow Copy : [[1, 2], [3, 4], [5, 100]]'

# %% [markdown]
# # 10

# %%
import copy
class Student:
    def __init__(self, name, marks):
        self.name=name
        self.marks=marks
Student1=Student("hari",[85,90,65])
Student2=copy.copy(Student1)
Student2=copy.deepcopy(Student1)
print(Student1.marks)
print(Student2.marks)
# Out:
# [85, 90, 65]
# [85, 90, 65]

# %%
import copy
class Student:
    def __init__(self, name, marks):
        self.name=name
        self.marks=marks
Student1=Student("hari",[85,70,65])
Student2=copy.copy(Student1)
Student3=copy.deepcopy(Student1)
Student2.marks.append(90)
Student3.marks.append(95)
print(Student1.name,Student1.marks)
print(Student2.name,Student2.marks)
print(Student3.name,Student3.marks)
# Out:
# hari [85, 70, 65, 90]
# hari [85, 70, 65, 90]
# hari [85, 70, 65, 95]

# %% [markdown]
# # Oops Concept

# %% [markdown]
# # 1

# %%
class Student:
    def __init__(self,name,age,marks):
        self.name=name
        self.age=age
        self.marks=marks
    def display(self):
        print(f"student_name={self.name}")
        print(f"student_age={self.age}")
        print(f"student_marks={self.marks}")
std1 = Student("Haritha",22,70)
std2 = Student("Akshitha",21,80)
std1.display()
std2.display()
# Out:
# student_name=Haritha
# student_age=22
# student_marks=70
# student_name=Akshitha
# student_age=21
# student_marks=80

# %% [markdown]
# # 2

# %%
class Employee:
    def __init__(self,emp_id,name,salary):
        self.emp_id=emp_id
        self.name=name
        self.salary=salary
    def increase_salary(self):
        self.salary+=5000
        print(f"increased salary:{self.salary}")
emp1=Employee(426,"Hari",20000)
emp1.increase_salary()
# Out:
# increased salary:25000

# %% [markdown]
# # 3

# %%
class Mobile:
    def __init__(self, brand, model, price):
        self.brand = brand
        self.model = model
        self.price = price
        
    def apply_discount(self):
        self.price = self.price - (self.price * 10 / 100)
    def display_information(self):
        print(f"Mobile Brand:{self.brand}")
        print(f"Mobile Model:{self.model}")
        print(f"Mobile Price:{self.price}")
            
mobile = Mobile("iPhone",17,50000)
mobile.apply_discount()
mobile.display_information()
# Out:
# Mobile Brand:iPhone
# Mobile Model:17
# Mobile Price:45000.0

# %% [markdown]
# # 4

# %%
class Laptop:
    def __init__(self, brand, ram, storage):
        self.brand = brand
        self.ram = ram
        self.storage = storage
        
    def upgrade_ram(self):
        self.ram += 8
    def display_information(self):
        print(f"Laptop Brand:{self.brand}")
        print(f"Laptop RAM:{self.ram} GB")
        print(f"Laptop STORAGE:{self.storage} GB")
            
laptop = Laptop("Dell", 8, 512)

print("Before RAM Upgrade:")
laptop.display_information()

laptop.upgrade_ram()

print("\nAfter RAM Upgrade:")
laptop.display_information()
# Out:
# Before RAM Upgrade:
# Laptop Brand:Dell
# Laptop RAM:8 GB
# Laptop STORAGE:512 GB
#
# After RAM Upgrade:
# Laptop Brand:Dell
# Laptop RAM:16 GB
# Laptop STORAGE:512 GB

# %% [markdown]
# # 5

# %%
class BankAccount:
    def __init__(self, account_holder, balance):
        self.account_holder = account_holder
        self.balance = balance
    def deposit(self, amount):
        self.balance=self.balance+amount
    def withdraw(self, amount):
        if amount<= self.balance:
            self.balance=self.balance-amount
            print("withdraw successful")
        else:
            print("Insufficient balance")
    def display_information(self):
        print(f" account_holder  : {self.account_holder}")
        print(f" balance  : {self.balance}")
A=BankAccount("Sandhya",20000)
A.display_information()
A.deposit(1000)
A.withdraw(2000)
A.display_information()
# Out:
#  account_holder  : Sandhya
#  balance  : 20000
# withdraw successful
#  account_holder  : Sandhya
#  balance  : 19000

# %% [markdown]
# # 6

# %%
class CarSpeed:
    def __init__(self, brand, speed):
        self.brand = brand
        self.speed = speed  
    def increase_speed(self, value):
        if self.speed+value<=200:
            self.speed=self.speed+value
        else:
            self.speed=200
    def display_information(self):
        print(f"car brand:{self.brand}")
        print(f"car speed:{self.speed}","Km/h")
C=CarSpeed("BMW",100)
C.display_information()
C.increase_speed(20)
C.display_information()
# Out:
# car brand:BMW
# car speed:100 Km/h
# car brand:BMW
# car speed:120 Km/h

# %% [markdown]
# # 7

# %%
class Temperature:
    def __init__(self,temperature):
        self.temperature=temperature
    def set_temperature(self,value):
        if value>=-20 and value<=50:
            self.temperature=value
        else:
            print("Invalid")
    def display_information(self):
         print(f" Temperature:{self.temperature}")
T=Temperature(20)
print("Before")
T.display_information()
T.set_temperature(60)
print("After")
T.display_information()
# Out:
# Before
#  Temperature:20
# Invalid
# After
#  Temperature:20

# %%
class Temperature:
    def __init__(self,temperature):
        self.temperature=temperature
    def set_temperature(self,value):
        if value>=-20 and value<=50:
            self.temperature=value
        else:
            print("Invalid")
    def display_information(self):
         print(f" Temperature:{self.temperature}")
T=Temperature(20)
print("Before")
T.display_information()
T.set_temperature(40)
print("After")
T.display_information()
# Out:
# Before
#  Temperature:20
# After
#  Temperature:40

# %% [markdown]
# # 8

# %%
class MovieTicket:
    def __init__(self, movie_name, seats):
        self.movie_name = movie_name
        self.seats = seats  
    def book_ticket(self, number):
        if number<=self.seats:
            self.seats=self.seats-number
            print("seats will available")
        else:
            print("Not sufficient")
    def display_information(self):
        print(f" movie_name:{self.movie_name}")
        print(f" seats:{self.seats}")
M=MovieTicket("Fidda",100)
M.display_information()
M.book_ticket(5)
M.display_information()
# Out:
#  movie_name:Fidda
#  seats:100
# seats will available
#  movie_name:Fidda
#  seats:95

# %% [markdown]
# # 9

# %%
class Library:
    def __init__(self, book_name, available_copies):
        self.book_name = book_name
        self.available_copies = available_copies 
    def borrow_book(self):
        if self.available_copies > 0:
            self.available_copies -= 1
            print("Book Borrowed successfully")
        else:
            print("Not sufficient")
    def display_information(self):
        print(f"Book_Name:{self.book_name}")
        print(f"Available_Copies:{self.available_copies}")
L=Library("Maths",10)
L.display_information()
L.borrow_book()
L.display_information()
# Out:
# Book_Name:Maths
# Available_Copies:10
# Book Borrowed successfully
# Book_Name:Maths
# Available_Copies:9

# %% [markdown]
# # 10

# %%
class Product:
    def __init__(self, product_name, quantity):
        self.product_name = product_name 
        self.quantity = quantity
    def sell(self,quantity):
        if quantity<= self.quantity:
            self.quantity-= quantity
            print("Product sold successfully")
        else:
            print("Insufficient quantity")
    def display_information(self):
        print(f"product_name:{self.product_name}")
        print(f"quantity:{self.quantity}")
P1=Product("Laptop",20)
P1.display_information()
P1.sell(4)
P1.display_information()
# Out:
# product_name:Laptop
# quantity:20
# Product sold successfully
# product_name:Laptop
# quantity:16

# %% [markdown]
# # 11

# %%
class StudentResult:
    def __init__(self, name, marks):
        self.name = name 
        self.marks = marks
    def update_marks(self,new_marks):
        if 0<=new_marks<=100:
            self.marks=new_marks
            print("marks updated successfully")
        else:
            print("Invalid marks")
    def display_information(self):
        print(f"name:{self.name}")
        print(f"marks:{self.marks}")
S1=StudentResult("Haritha",80)
S1.display_information()
S1.update_marks(60)
S1.display_information()
# Out:
# name:Haritha
# marks:80
# marks updated successfully
# name:Haritha
# marks:60

# %% [markdown]
# # 12

# %%
class EmployeeBonus:
    def __init__(self, name, salary):
        self.name = name 
        self.salary = salary
    def apply_bonus(self):
        if self.salary>= 40000:
            self.salary= self.salary+(self.salary*20/100)
        else:
            self.salary= self.salary+(self.salary*10/100)
    def display_information(self):
        print(f"name:{self.name}")
        print(f"salary:{self.salary}")
E1=EmployeeBonus("Haritha",20000)
E1.display_information()
E1.apply_bonus()
E1.display_information()
# Out:
# name:Haritha
# salary:20000
# name:Haritha
# salary:22000.0

# %% [markdown]
# # 13

# %%
class FuelTank:
    def __init__(self, capacity, current_fuel):
        self.capacity = capacity
        self.current_fuel = current_fuel
    def fill(self,amount):
        if self.current_fuel+amount<=self.capacity:
            self.current_fuel= self.current_fuel+amount
            print("Fuel filled successfully")
        else:
            print("Cannot fill")
    def display_information(self):
        print(f"capacity:{self.capacity}")
        print(f"current_fuel:{self.current_fuel}")
F1=FuelTank(60,80)
F1.display_information()
F1.fill(20)
F1.display_information()
# Out:
# capacity:60
# current_fuel:80
# Cannot fill
# capacity:60
# current_fuel:80

# %% [markdown]
# # 14

# %%
class PhoneBattery:
    def __init__(self, battery):
        self.battery = battery
    def charge(self,value):
        if self.battery+value<=100:
            self.battery += value
        else:
            self.battery=100
            print("Battery Charged successfully")
            
    def display_information(self):
        print(f"battery:{self.battery}","%")        
P1=PhoneBattery(70)
P1.display_information()
P1.charge(10)
P1.display_information()
# Out:
# battery:70 %
# battery:80 %

# %% [markdown]
# # 15

# %%
class Wallet:
    def __init__(self, owner, balance):
        self.owner = owner
        self.balance = balance
    def purchase(self,amount):
        if amount<=self.balance:
            self.balance -= amount
            print("Purchase successful")
        else:
            print("Insuffient balance")
            
    def display_information(self):
        print(f"owner:{self.owner}",)  
        print(f"balance:{self.balance}",)  
W1=Wallet("Hari",2000)
W1.display_information()
W1.purchase(500)
W1.display_information()
# Out:
# owner:Hari
# balance:2000
# Purchase successful
# owner:Hari
# balance:1500

# %% [markdown]
# # 16

# %%
class CricketPlayer:
    def __init__(self, player_name, total_runs, matches):
        self.player_name = player_name
        self.total_runs = total_runs
        self.matches = matches
    def add_runs(self,run):
        self.total_runs += run
        average = self.total_runs/self.matches
        print("Average:", average)
    def display_information(self):        
        print(f"player_name:{self.player_name}")
        print(f"total_runs:{self.total_runs}")
        print(f"matches:{self.matches}")
C1=CricketPlayer("Hardik",2000,100)
C1.display_information()
C1.add_runs(50)
C1.display_information()
# Out:
# player_name:Hardik
# total_runs:2000
# matches:100
# Average: 20.5
# player_name:Hardik
# total_runs:2050
# matches:100

# %% [markdown]
# # 17

# %%
class SchoolFees:
    def __init__(self, student_name, total_fee, paid_fee):
        self.student_name = student_name
        self.total_fee = total_fee
        self.paid_fee = paid_fee
    def pay_fee(self,amount):
        if self.paid_fee+amount<=self.total_fee:
            self.paid_fee += amount
            print("Fee paid successfully")
        else:
            print("Cannot pay")
            
    def display_information(self):        
        print(f"student_name:{self.student_name}")
        print(f"total_fee:{self.total_fee}")
        print(f"paid_fee:{self.paid_fee}")
S1=SchoolFees("Hardik",20000,10000)
S1.display_information()
S1.pay_fee(5000)
S1.display_information()
# Out:
# student_name:Hardik
# total_fee:20000
# paid_fee:10000
# Fee paid successfully
# student_name:Hardik
# total_fee:20000
# paid_fee:15000

# %% [markdown]
# # 18

# %%
class HospitalPatient:
    def __init__(self, patient_name, age, temperature):
        self.patient_name = patient_name
        self.age = age
        self.temperature = temperature
    def update_temperature(self, temp):
        if temp>102:
            print("Emergency")
        else:
            self.temperature=temp
            print("Temperature Updated")
            
    def display_information(self):        
        print(f"patient_name:{self.patient_name}")
        print(f"age:{self.age}")
        print(f"temperature:{self.temperature}")
H1=HospitalPatient("Hardik",60,100)
H1.display_information()
H1.update_temperature(50)
H1.display_information()
# Out:
# patient_name:Hardik
# age:60
# temperature:100
# Temperature Updated
# patient_name:Hardik
# age:60
# temperature:50

# %% [markdown]
# # 19

# %%
class ATM:
    def __init__(self, balance):
        self.balance = balance
    def deposite(self, amount):
        if amount>0:
            self.balance += amount
            print("Deposited")
        else:
            print("Invalid amount")
    def withdraw(self, amount):
         if amount<=0:
            print("Invalid amount")
         elif amount>self.balance:
             print("Insufficient Balance")
         else:
             self.balance-=amount
             print("Amount withdrawn")
             
    def display_information(self):
         print(f"balance:{self.balance}")
A1=ATM(6000)
A1.display_information()
A1.deposite(3000)
A1.withdraw(1000)
A1.display_information()
# Out:
# balance:6000
# Deposited
# Amount withdrawn
# balance:8000

# %% [markdown]
# # 20

# %%
class HotelRoom:
    def __init__(self, room_number, occupied):
        self.room_number = room_number
        self.occupied = occupied
    def book(self):
        if self.occupied:
            print("Room is already booked")
        else:
            self.occupied=True
            print("Room booked successfully")
            
    def display_information(self):        
        print(f"room_number:{self.room_number}")
        print(f"occupied:{self.occupied}")
H1=HotelRoom(201,"True")
H1.display_information()
# Out:
# room_number:201
# occupied:True

# %% [markdown]
# # 21

# %%
class inventorysystem:
    def __init__(self, product_name, stock):
        self.product_name = product_name
        self.stock =  stock  
    def update_stock(self, change):
        if self.stock + change >= 0:
            self.stock = self.stock + change
            print("stock:",self.stock)
        else:
            print("stock cannot become negative")
item= inventorysystem("laptop",40)
item.update_stock(30)
# Out:
# stock: 70

# %% [markdown]
# # 22

# %%
class EmployeePerformance:
    def __init__(self, employee_name, rating):
        self.employee_name = employee_name
        self.rating = rating
    def update_rating(self, new_rating):
        if 1 <= new_rating <=5:
            self.rating = new_rating
            print("current rating:",self.rating)
            if self.rating == 5:
                print("Excellent")
        else:
            print("invalid")
employee=EmployeePerformance("Hari",4)
employee.update_rating(8)
# Out:
# invalid

# %% [markdown]
# # 23
