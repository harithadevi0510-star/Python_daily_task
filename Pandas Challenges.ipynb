# %% [markdown]
# # Pandas Challenges

# %% [markdown]
# Challenge 1 – Complete Data Cleaning
# Your manager gives you a messy dataset.
# Perform all of the following:
# • Load the dataset.
# • Display dataset information.
# • Find missing values.
# • Remove duplicate rows.
# • Fill missing values:
# o Age → median
# o Balance → mean
# • Rename:
# o Target → CustomerStatus
# o AnnualIncome → Income
# • Display the first 15 rows.

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
df.isnull()
# Out:
#       CustomerID    Age  AnnualIncome  Spending  CreditScore  Balance  Tenure  \
# 0          False  False         False     False        False     True   False
# 1          False  False         False     False        False    False   False
# 2          False  False         False     False        False    False   False
# 3          False  False         False     False        False    False   False
# 4          False  False         False     False        False    False   False
# ...          ...    ...           ...       ...          ...      ...     ...
# 1015       False  False         False     False        False    False   False
# 1016       False  False         False     False        False    False   False
# 1017       False  False         False     False        False    False   False
# 1018       False  False          True     False        False    False   False
# 1019       False  False         False     False        False     True   False
#
#       Geography  Gender  Segment  Target
# 0         False   False    False   False
# 1         False   False    False   False
# 2         False   False    False   False
# 3          True   False    False   False
# 4         False   False    False   False
# ...         ...     ...      ...     ...
# 1015      False   False    False   False
# 1016      False    True    False   False
# 1017      False   False    False   False
# 1018      False   False    False   False
# 1019      False   False     True   False
#
# [1020 rows x 11 columns]

# %%
df.drop_duplicates()
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
# ..          ...   ...           ...       ...          ...        ...     ...
# 995       10996  34.0       81731.0     40980          761  181465.65       5
# 996       10997  47.0       42475.0      1176          780   26640.99       5
# 997       10998  31.0      120531.0     46929          733  147220.82       4
# 998       10999  21.0       33661.0     22314          540   94186.48       5
# 999       11000  63.0       31930.0       851          559  100908.40       6
#
#     Geography  Gender    Segment Target
# 0      France    Male        SME   Stay
# 1         USA    Male        SME  Churn
# 2      Canada    Male  Corporate   Stay
# 3         NaN    Male     Retail  Churn
# 4          UK   Other  Corporate  Churn
# ..        ...     ...        ...    ...
# 995   Germany   Other        SME   Stay
# 996    France  Female        SME   Stay
# 997     India    Male        SME   Stay
# 998       NaN   Other        SME   Stay
# 999        UK  Female        NaN   Stay
#
# [1000 rows x 11 columns]

# %%
df["Age"]=df["Age"].fillna(df['Age'].median())
print(df['Age'].isnull().sum())
# Out:
# 0

# %%
df["Balance"]=df["Balance"].fillna(df['Balance'].mean())
print(df['Balance'].isnull().sum())
# Out:
# 0

# %%
df=df.rename(columns={"Target" : "CustomerStatus",
                      "AnnualIncome" : "Income"})
df.head(15)
# Out:
#     CustomerID   Age    Income  Spending  CreditScore        Balance  Tenure  \
# 0        10001  58.0   49184.0      2139          581   97523.535666       2
# 1        10002  65.0  162964.0      6197          732    6356.540000       1
# 2        10003  56.0   26956.0     37281          503  143203.920000       8
# 3        10004  55.0   92926.0       925          463  139627.880000       5
# 4        10005  66.0  108236.0      7198          394   75985.460000       5
# 5        10006  69.0   31390.0     48323          770  107245.620000       6
# 6        10007  58.0  182141.0     24200          891   38457.720000       1
# 7        10008  67.0   95861.0      5729          538  173296.730000       6
# 8        10009  41.0   62638.0     24760          663   41901.410000       4
# 9        10010  22.0  179680.0     42113          475  106827.980000       3
# 10       10011  44.0  187772.0     45599          870   43923.030000       5
# 11       10012  69.0  102694.0     26790          574   13237.720000       9
# 12       10013  59.0  150870.0     26428          769   28574.320000       2
# 13       10014  52.0   88876.0     49456          898   85686.770000       9
# 14       10015  26.0  153569.0     32843          393  151156.430000       1
#
#    Geography  Gender    Segment CustomerStatus
# 0     France    Male        SME           Stay
# 1        USA    Male        SME          Churn
# 2     Canada    Male  Corporate           Stay
# 3        NaN    Male     Retail          Churn
# 4         UK   Other  Corporate          Churn
# 5      India   Other  Corporate           Stay
# 6      India   Other     Retail          Churn
# 7         UK  Female        SME           Stay
# 8     France   Other        SME           Stay
# 9        USA  Female  Corporate          Churn
# 10     India     NaN     Retail           Stay
# 11    France  Female     Retail          Churn
# 12       USA   Other        SME           Stay
# 13    Canada  Female     Retail           Stay
# 14       USA   Other     Retail          Churn

# %% [markdown]
# Challenge 2 – Banking Report
# The bank wants a numeric report.
# Tasks
# • Select only numeric columns.
# • Display summary statistics.
# • Convert Age and CreditScore to float.
# • Display information again.

# %%
numeric_df=df.select_dtypes(include='number')
print(numeric_df.head())
print(numeric_df.describe())
# Out:
#    CustomerID   Age    Income  Spending  CreditScore        Balance  Tenure
# 0       10001  58.0   49184.0      2139          581   97523.535666       2
# 1       10002  65.0  162964.0      6197          732    6356.540000       1
# 2       10003  56.0   26956.0     37281          503  143203.920000       8
# 3       10004  55.0   92926.0       925          463  139627.880000       5
# 4       10005  66.0  108236.0      7198          394   75985.460000       5
#          CustomerID          Age         Income      Spending  CreditScore  \
# count   1020.000000  1020.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112505.928645  25232.615686   602.659804
# std      288.022115    15.136428   52303.362541  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   66149.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  158000.500000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1020.000000  1020.000000
# mean    97523.535666     5.261765
# std     54382.357541     3.185330
# min       547.600000     0.000000
# 25%     52145.757500     2.000000
# 50%     97523.535666     5.000000
# 75%    142086.700000     8.000000
# max    199885.880000    10.000000

# %%
df['Age']=df['Age'].astype(float)
df['CreditScore']=df['CreditScore'].astype(float)

# %%
df['Age']
df['CreditScore']
# Out:
# 0       581.0
# 1       732.0
# 2       503.0
# 3       463.0
# 4       394.0
#         ...
# 1015    644.0
# 1016    303.0
# 1017    813.0
# 1018    722.0
# 1019    430.0
# Name: CreditScore, Length: 1020, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      1020 non-null   int64
#  1   Age             1020 non-null   float64
#  2   Income          967 non-null    float64
#  3   Spending        1020 non-null   int64
#  4   CreditScore     1020 non-null   float64
#  5   Balance         1020 non-null   float64
#  6   Tenure          1020 non-null   int64
#  7   Geography       969 non-null    object
#  8   Gender          968 non-null    object
#  9   Segment         969 non-null    object
#  10  CustomerStatus  1020 non-null   object
# dtypes: float64(4), int64(3), object(4)
# memory usage: 87.8+ KB

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %% [markdown]
# Challenge 3 – Duplicate Investigation
# Find duplicate customers.
# Then
# • Count duplicate rows.
# • Remove duplicates.
# • Print information before and after removing duplicates.
# • Show the last 20 rows.

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)
df.info()
df.tail(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1000 non-null   int64
#  1   Age           950 non-null    float64
#  2   AnnualIncome  950 non-null    float64
#  3   Spending      1000 non-null   int64
#  4   CreditScore   1000 non-null   int64
#  5   Balance       950 non-null    float64
#  6   Tenure        1000 non-null   int64
#  7   Geography     950 non-null    object
#  8   Gender        950 non-null    object
#  9   Segment       950 non-null    object
#  10  Target        1000 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 980       10981  41.0      199633.0      8498          847  173390.59       7
# 981       10982  34.0       98876.0      6414          541   59484.58       2
# 982       10983  69.0      188933.0     27126          334        NaN       1
# 983       10984  44.0      107221.0     47514          732  175352.25       1
# 984       10985  50.0       37397.0     23559          730  120423.19       8
# 985       10986  62.0       27169.0      3914          488  126031.27      10
# 986       10987  30.0      184704.0     20524          621  115161.87       1
# 987       10988  63.0      190178.0      9025          720  158528.46       5
# 988       10989  26.0       88335.0     11869          635  159905.73       3
# 989       10990  29.0      123152.0     25228          884   44897.43       0
# 990       10991  58.0       79954.0      6331          773   39653.24       2
# 991       10992  45.0           NaN     17549          452   17812.25       5
# 992       10993  18.0      157845.0     29018          764  165451.49       7
# 993       10994  31.0       69950.0     17945          594  149288.61       6
# 994       10995  56.0       76509.0     19044          493   83666.20       6
# 995       10996  34.0       81731.0     40980          761  181465.65       5
# 996       10997  47.0       42475.0      1176          780   26640.99       5
# 997       10998  31.0      120531.0     46929          733  147220.82       4
# 998       10999  21.0       33661.0     22314          540   94186.48       5
# 999       11000  63.0       31930.0       851          559  100908.40       6
#
#     Geography  Gender    Segment Target
# 980    Canada    Male  Corporate   Stay
# 981    Canada   Other  Corporate   Stay
# 982    Canada  Female        SME  Churn
# 983       USA   Other  Corporate  Churn
# 984    France  Female  Corporate   Stay
# 985       USA    Male  Corporate  Churn
# 986       USA    Male        SME  Churn
# 987       NaN  Female        SME   Stay
# 988     India  Female  Corporate   Stay
# 989   Germany   Other        SME  Churn
# 990     India  Female        SME   Stay
# 991       USA   Other     Retail  Churn
# 992     India    Male        SME   Stay
# 993       USA  Female     Retail   Stay
# 994       USA    Male  Corporate  Churn
# 995   Germany   Other        SME   Stay
# 996    France  Female        SME   Stay
# 997     India    Male        SME   Stay
# 998       NaN   Other        SME   Stay
# 999        UK  Female        NaN   Stay

# %% [markdown]
# Challenge 4 – HR Department
# HR wants better column names.
# Rename
# CustomerID → Employee_ID
# Age → EmployeeAge
# Gender → EmployeeGender
# AnnualIncome → Salary
# Target → PromotionStatus
# Then
# • Add prefix
# HR_
# to every column.
# Display 10 random records.

# %%
df=df.rename(columns={
    "CustomerID":"Employee_ID",
    "Age":"EmployeeAge",
    "Gender":"EmployeeGender",
    "AnnualIncome":"Salary",
    "Target":"PromotionStatus"})
df
# Out:
#      Employee_ID  EmployeeAge    Salary  Spending  CreditScore    Balance  \
# 0          10001         58.0   49184.0      2139          581        NaN
# 1          10002         65.0  162964.0      6197          732    6356.54
# 2          10003         56.0   26956.0     37281          503  143203.92
# 3          10004         55.0   92926.0       925          463  139627.88
# 4          10005         66.0  108236.0      7198          394   75985.46
# ..           ...          ...       ...       ...          ...        ...
# 995        10996         34.0   81731.0     40980          761  181465.65
# 996        10997         47.0   42475.0      1176          780   26640.99
# 997        10998         31.0  120531.0     46929          733  147220.82
# 998        10999         21.0   33661.0     22314          540   94186.48
# 999        11000         63.0   31930.0       851          559  100908.40
#
#      Tenure Geography EmployeeGender    Segment PromotionStatus
# 0         2    France           Male        SME            Stay
# 1         1       USA           Male        SME           Churn
# 2         8    Canada           Male  Corporate            Stay
# 3         5       NaN           Male     Retail           Churn
# 4         5        UK          Other  Corporate           Churn
# ..      ...       ...            ...        ...             ...
# 995       5   Germany          Other        SME            Stay
# 996       5    France         Female        SME            Stay
# 997       4     India           Male        SME            Stay
# 998       5       NaN          Other        SME            Stay
# 999       6        UK         Female        NaN            Stay
#
# [1000 rows x 11 columns]

# %%
df=df.add_prefix("HR_")
df
# Out:
#      HR_Employee_ID  HR_EmployeeAge  HR_Salary  HR_Spending  HR_CreditScore  \
# 0             10001            58.0    49184.0         2139             581
# 1             10002            65.0   162964.0         6197             732
# 2             10003            56.0    26956.0        37281             503
# 3             10004            55.0    92926.0          925             463
# 4             10005            66.0   108236.0         7198             394
# ..              ...             ...        ...          ...             ...
# 995           10996            34.0    81731.0        40980             761
# 996           10997            47.0    42475.0         1176             780
# 997           10998            31.0   120531.0        46929             733
# 998           10999            21.0    33661.0        22314             540
# 999           11000            63.0    31930.0          851             559
#
#      HR_Balance  HR_Tenure HR_Geography HR_EmployeeGender HR_Segment  \
# 0           NaN          2       France              Male        SME
# 1       6356.54          1          USA              Male        SME
# 2     143203.92          8       Canada              Male  Corporate
# 3     139627.88          5          NaN              Male     Retail
# 4      75985.46          5           UK             Other  Corporate
# ..          ...        ...          ...               ...        ...
# 995   181465.65          5      Germany             Other        SME
# 996    26640.99          5       France            Female        SME
# 997   147220.82          4        India              Male        SME
# 998    94186.48          5          NaN             Other        SME
# 999   100908.40          6           UK            Female        NaN
#
#     HR_PromotionStatus
# 0                 Stay
# 1                Churn
# 2                 Stay
# 3                Churn
# 4                Churn
# ..                 ...
# 995               Stay
# 996               Stay
# 997               Stay
# 998               Stay
# 999               Stay
#
# [1000 rows x 11 columns]

# %%
df.sample(10)
# Out:
#      HR_Employee_ID  HR_EmployeeAge  HR_Salary  HR_Spending  HR_CreditScore  \
# 722           10723            59.0    22184.0         4864             697
# 10            10011             NaN   187772.0        45599             870
# 138           10139            35.0    22122.0        37588             350
# 757           10758            29.0    62293.0        44546             591
# 350           10351            19.0   141011.0        46923             514
# 608           10609            20.0   159311.0        33486             420
# 190           10191            20.0    34913.0        24665             593
# 617           10618            46.0    62413.0         7071             519
# 988           10989            26.0    88335.0        11869             635
# 378           10379            31.0   174120.0        45663             659
#
#      HR_Balance  HR_Tenure HR_Geography HR_EmployeeGender HR_Segment  \
# 722   132074.57         10       France            Female     Retail
# 10     43923.03          5        India               NaN     Retail
# 138   182123.39          7           UK              Male        SME
# 757   122217.95          9      Germany             Other     Retail
# 350    87690.99          4       France               NaN  Corporate
# 608    18637.99         10          USA             Other        SME
# 190    15346.20          1      Germany             Other        SME
# 617   101668.71          5      Germany             Other        SME
# 988   159905.73          3        India            Female  Corporate
# 378   172209.74          9       France            Female     Retail
#
#     HR_PromotionStatus
# 722               Stay
# 10                Stay
# 138              Churn
# 757               Stay
# 350               Stay
# 608              Churn
# 190              Churn
# 617               Stay
# 988               Stay
# 378               Stay

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %% [markdown]
# Challenge 5 – Finance Cleaning
# Finance department reports missing values.
# Tasks
# Fill
# AnnualIncome → Median
# Balance → Mean
# Age → Median
# Then
# Generate descriptive statistics.

# %%
df['AnnualIncome']=df['AnnualIncome'].fillna(df['AnnualIncome'].median())
df['Balance']=df['Balance'].fillna(df['Balance'].mean())
df['Age']=df['Age'].fillna(df['Age'].median())
df.describe()
# Out:
#          CustomerID          Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  1020.000000    1020.000000   1020.000000  1020.000000
# mean   10501.599020    44.237255  112498.242157  25232.615686   602.659804
# std      288.022115    15.136428   50925.015723  14219.393105   176.560690
# min    10001.000000    18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000    31.000000   69223.000000  13134.750000   440.750000
# 50%    10502.500000    44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000    57.000000  155570.750000  37956.000000   757.250000
# max    11000.000000    70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count    1020.000000  1020.000000
# mean    97523.535666     5.261765
# std     54382.357541     3.185330
# min       547.600000     0.000000
# 25%     52145.757500     2.000000
# 50%     97523.535666     5.000000
# 75%    142086.700000     8.000000
# max    199885.880000    10.000000

# %% [markdown]
# Challenge 6 – Data Type Audit
# The company says
# Age and AnnualIncome are stored incorrectly.
# Tasks
# Convert
# Age → int
# AnnualIncome → float
# Balance → float
# Target → string
# Print information.

# %%
df['Age']=df['Age'].astype(int)
df['AnnualIncome']=df['AnnualIncome'].astype(float)
df['Balance']=df['Balance'].astype(float)
df['Target']=df['Target'].astype(str)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           1020 non-null   int32
#  2   AnnualIncome  1020 non-null   float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       1020 non-null   float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(2), int32(1), int64(4), object(4)
# memory usage: 83.8+ KB

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'AnnualIncome', 'Spending', 'CreditScore',
#        'Balance', 'Tenure', 'Geography', 'Gender', 'Segment', 'Target'],
#       dtype='object')

# %% [markdown]
# Challenge 7 – Customer Analytics
# Create a new DataFrame that
# • removes Segment
# • removes Geography
# • removes duplicate rows
# Display
# • first 10 rows
# • dataset information
# • statistical summary

# %%
new_df=df.drop(columns=["Segment","Geography"])
new_df=new_df.drop_duplicates()
new_df.head(10)
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
# 5       10006  69.0       31390.0     48323          770  107245.62       6
# 6       10007  58.0      182141.0     24200          891   38457.72       1
# 7       10008  67.0       95861.0      5729          538  173296.73       6
# 8       10009  41.0       62638.0     24760          663   41901.41       4
# 9       10010  22.0      179680.0     42113          475  106827.98       3
#
#    Gender Target
# 0    Male   Stay
# 1    Male  Churn
# 2    Male   Stay
# 3    Male  Churn
# 4   Other  Churn
# 5   Other   Stay
# 6   Other  Churn
# 7  Female   Stay
# 8   Other   Stay
# 9  Female  Churn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1020 non-null   int64
#  1   Age           970 non-null    float64
#  2   AnnualIncome  967 non-null    float64
#  3   Spending      1020 non-null   int64
#  4   CreditScore   1020 non-null   int64
#  5   Balance       969 non-null    float64
#  6   Tenure        1020 non-null   int64
#  7   Geography     969 non-null    object
#  8   Gender        968 non-null    object
#  9   Segment       969 non-null    object
#  10  Target        1020 non-null   object
# dtypes: float64(3), int64(4), object(4)
# memory usage: 87.8+ KB

# %%
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure
# count     969.000000  1020.000000
# mean    97523.535666     5.261765
# std     55796.562543     3.185330
# min       547.600000     0.000000
# 25%     50077.860000     2.000000
# 50%     95100.060000     5.000000
# 75%    143947.810000     8.000000
# max    199885.880000    10.000000

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %% [markdown]
# Challenge 8 – ML Dataset Preparation
# Prepare a machine learning dataset.
# Perform
# • Remove duplicates
# • Remove CustomerID
# • Remove Segment
# • Fill missing values
# • Rename Target to Output
# Finally
# Display
# head()
# info()
# describe()
# value_counts(Output)

# %%
df=df.drop_duplicates()
df
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
# ..          ...   ...           ...       ...          ...        ...     ...
# 995       10996  34.0       81731.0     40980          761  181465.65       5
# 996       10997  47.0       42475.0      1176          780   26640.99       5
# 997       10998  31.0      120531.0     46929          733  147220.82       4
# 998       10999  21.0       33661.0     22314          540   94186.48       5
# 999       11000  63.0       31930.0       851          559  100908.40       6
#
#     Geography  Gender    Segment Target
# 0      France    Male        SME   Stay
# 1         USA    Male        SME  Churn
# 2      Canada    Male  Corporate   Stay
# 3         NaN    Male     Retail  Churn
# 4          UK   Other  Corporate  Churn
# ..        ...     ...        ...    ...
# 995   Germany   Other        SME   Stay
# 996    France  Female        SME   Stay
# 997     India    Male        SME   Stay
# 998       NaN   Other        SME   Stay
# 999        UK  Female        NaN   Stay
#
# [1000 rows x 11 columns]

# %%
df=df.drop(columns=["CustomerID","Segment"])
df
# Out:
#       Age  AnnualIncome  Spending  CreditScore    Balance  Tenure Geography  \
# 0    58.0       49184.0      2139          581        NaN       2    France
# 1    65.0      162964.0      6197          732    6356.54       1       USA
# 2    56.0       26956.0     37281          503  143203.92       8    Canada
# 3    55.0       92926.0       925          463  139627.88       5       NaN
# 4    66.0      108236.0      7198          394   75985.46       5        UK
# ..    ...           ...       ...          ...        ...     ...       ...
# 995  34.0       81731.0     40980          761  181465.65       5   Germany
# 996  47.0       42475.0      1176          780   26640.99       5    France
# 997  31.0      120531.0     46929          733  147220.82       4     India
# 998  21.0       33661.0     22314          540   94186.48       5       NaN
# 999  63.0       31930.0       851          559  100908.40       6        UK
#
#      Gender Target
# 0      Male   Stay
# 1      Male  Churn
# 2      Male   Stay
# 3      Male  Churn
# 4     Other  Churn
# ..      ...    ...
# 995   Other   Stay
# 996  Female   Stay
# 997    Male   Stay
# 998   Other   Stay
# 999  Female   Stay
#
# [1000 rows x 9 columns]

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")

# %%
numeric_cols=df.select_dtypes(include="number").columns
df[numeric_cols]=df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
df[numeric_cols]
# Out:
#       CustomerID   Age   AnnualIncome  Spending  CreditScore        Balance  \
# 0          10001  58.0   49184.000000      2139          581   97523.535666
# 1          10002  65.0  162964.000000      6197          732    6356.540000
# 2          10003  56.0   26956.000000     37281          503  143203.920000
# 3          10004  55.0   92926.000000       925          463  139627.880000
# 4          10005  66.0  108236.000000      7198          394   75985.460000
# ...          ...   ...            ...       ...          ...            ...
# 1015       10450  43.0  173620.000000      7121          644   60353.030000
# 1016       10753  25.0   54490.000000     13794          303  124512.070000
# 1017       10810  49.0   82062.000000     47170          813   53850.090000
# 1018       10267  38.0  112505.928645     10424          722  138100.050000
# 1019       10059  62.0   97504.000000     36833          430   97523.535666
#
#       Tenure
# 0          2
# 1          1
# 2          8
# 3          5
# 4          5
# ...      ...
# 1015       2
# 1016       4
# 1017       8
# 1018       6
# 1019      10
#
# [1020 rows x 7 columns]

# %%
df=df.rename(columns={
    "Target":"Output"})
df
# Out:
#       Age  AnnualIncome  Spending  CreditScore    Balance  Tenure Geography  \
# 0    58.0       49184.0      2139          581        NaN       2    France
# 1    65.0      162964.0      6197          732    6356.54       1       USA
# 2    56.0       26956.0     37281          503  143203.92       8    Canada
# 3    55.0       92926.0       925          463  139627.88       5       NaN
# 4    66.0      108236.0      7198          394   75985.46       5        UK
# ..    ...           ...       ...          ...        ...     ...       ...
# 995  34.0       81731.0     40980          761  181465.65       5   Germany
# 996  47.0       42475.0      1176          780   26640.99       5    France
# 997  31.0      120531.0     46929          733  147220.82       4     India
# 998  21.0       33661.0     22314          540   94186.48       5       NaN
# 999  63.0       31930.0       851          559  100908.40       6        UK
#
#      Gender Output
# 0      Male   Stay
# 1      Male  Churn
# 2      Male   Stay
# 3      Male  Churn
# 4     Other  Churn
# ..      ...    ...
# 995   Other   Stay
# 996  Female   Stay
# 997    Male   Stay
# 998   Other   Stay
# 999  Female   Stay
#
# [1000 rows x 9 columns]

# %%
df.head()
# Out:
#     Age  AnnualIncome  Spending  CreditScore    Balance  Tenure Geography  \
# 0  58.0       49184.0      2139          581        NaN       2    France
# 1  65.0      162964.0      6197          732    6356.54       1       USA
# 2  56.0       26956.0     37281          503  143203.92       8    Canada
# 3  55.0       92926.0       925          463  139627.88       5       NaN
# 4  66.0      108236.0      7198          394   75985.46       5        UK
#
#   Gender Output
# 0   Male   Stay
# 1   Male  Churn
# 2   Male   Stay
# 3   Male  Churn
# 4  Other  Churn

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Age           950 non-null    float64
#  1   AnnualIncome  950 non-null    float64
#  2   Spending      1000 non-null   int64
#  3   CreditScore   1000 non-null   int64
#  4   Balance       950 non-null    float64
#  5   Tenure        1000 non-null   int64
#  6   Geography     950 non-null    object
#  7   Gender        950 non-null    object
#  8   Output        1000 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 78.1+ KB

# %%
df.describe()
# Out:
#               Age   AnnualIncome      Spending  CreditScore        Balance  \
# count  950.000000     950.000000   1000.000000  1000.000000     950.000000
# mean    44.212632  112458.303158  25285.558000   603.088000   97557.565779
# std     15.524244   52409.868404  14211.735656   176.605486   55845.536430
# min     18.000000   20227.000000    537.000000   300.000000     547.600000
# 25%     30.000000   65922.500000  13213.000000   441.000000   50003.880000
# 50%     44.000000  112347.500000  24901.000000   606.500000   95174.625000
# 75%     58.000000  157973.000000  37960.250000   758.250000  144198.130000
# max     70.000000  199967.000000  49995.000000   900.000000  199885.880000
#
#             Tenure
# count  1000.000000
# mean      5.241000
# std       3.179155
# min       0.000000
# 25%       2.000000
# 50%       5.000000
# 75%       8.000000
# max      10.000000

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")

# %%
df.value_counts()
# Out:
# CustomerID  Age   AnnualIncome  Spending  CreditScore  Balance    Tenure  Geography  Gender  Segment    Target
# 10643       41.0  125012.0      18825     761          35977.85   2       Germany    Other   Retail     Stay      2
# 10417       70.0  40417.0       37956     681          23880.19   10      India      Male    Retail     Stay      2
# 10756       53.0  74430.0       3705      489          29651.23   10      UK         Male    Retail     Churn     2
# 10910       66.0  118506.0      6296      306          81892.13   4       Canada     Male    SME        Churn     2
# 10200       19.0  115052.0      20741     484          190233.86  5       Canada     Male    Retail     Churn     2
#                                                                                                                  ..
# 10338       36.0  84605.0       47234     375          16407.60   2       Canada     Other   SME        Churn     1
# 10339       27.0  122137.0      21253     669          21310.18   0       UK         Female  Corporate  Churn     1
# 10340       66.0  90717.0       7199      435          17459.45   6       Canada     Other   SME        Churn     1
# 10341       50.0  126966.0      7269      326          17923.77   8       India      Other   SME        Churn     1
# 10998       31.0  120531.0      46929     733          147220.82  4       India      Male    SME        Stay      1
# Name: count, Length: 742, dtype: int64

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df.head()
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target
# 0    France   Male        SME   Stay
# 1       USA   Male        SME  Churn
# 2    Canada   Male  Corporate   Stay
# 3       NaN   Male     Retail  Churn
# 4        UK  Other  Corporate  Churn

# %% [markdown]
# Challenge 9 – Column Transformation
# Create these new columns
# NetWorth = Balance + AnnualIncome
# AgeAfterRetirement = Age + 20
# DoubleCreditScore = CreditScore * 2
# IncomePerMonth = AnnualIncome / 12
# Then
# Display first 15 rows.

# %%
df["NetWorth"]=df["Balance"]+df["AnnualIncome"]
df["AgeAfterRetirement"]=df["Age"]+20
df["DoubleCreditScore"]=df["CreditScore"]*2
df["IncomePerMonth"]=df["AnnualIncome"]/12
df.head(15)
# Out:
#     CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0        10001  58.0       49184.0      2139          581        NaN       2
# 1        10002  65.0      162964.0      6197          732    6356.54       1
# 2        10003  56.0       26956.0     37281          503  143203.92       8
# 3        10004  55.0       92926.0       925          463  139627.88       5
# 4        10005  66.0      108236.0      7198          394   75985.46       5
# 5        10006  69.0       31390.0     48323          770  107245.62       6
# 6        10007  58.0      182141.0     24200          891   38457.72       1
# 7        10008  67.0       95861.0      5729          538  173296.73       6
# 8        10009  41.0       62638.0     24760          663   41901.41       4
# 9        10010  22.0      179680.0     42113          475  106827.98       3
# 10       10011   NaN      187772.0     45599          870   43923.03       5
# 11       10012  69.0      102694.0     26790          574   13237.72       9
# 12       10013  59.0      150870.0     26428          769   28574.32       2
# 13       10014  52.0       88876.0     49456          898   85686.77       9
# 14       10015  26.0      153569.0     32843          393  151156.43       1
#
#    Geography  Gender    Segment Target   NetWorth  AgeAfterRetirement  \
# 0     France    Male        SME   Stay        NaN                78.0
# 1        USA    Male        SME  Churn  169320.54                85.0
# 2     Canada    Male  Corporate   Stay  170159.92                76.0
# 3        NaN    Male     Retail  Churn  232553.88                75.0
# 4         UK   Other  Corporate  Churn  184221.46                86.0
# 5      India   Other  Corporate   Stay  138635.62                89.0
# 6      India   Other     Retail  Churn  220598.72                78.0
# 7         UK  Female        SME   Stay  269157.73                87.0
# 8     France   Other        SME   Stay  104539.41                61.0
# 9        USA  Female  Corporate  Churn  286507.98                42.0
# 10     India     NaN     Retail   Stay  231695.03                 NaN
# 11    France  Female     Retail  Churn  115931.72                89.0
# 12       USA   Other        SME   Stay  179444.32                79.0
# 13    Canada  Female     Retail   Stay  174562.77                72.0
# 14       USA   Other     Retail  Churn  304725.43                46.0
#
#     DoubleCreditScore  IncomePerMonth
# 0                1162     4098.666667
# 1                1464    13580.333333
# 2                1006     2246.333333
# 3                 926     7743.833333
# 4                 788     9019.666667
# 5                1540     2615.833333
# 6                1782    15178.416667
# 7                1076     7988.416667
# 8                1326     5219.833333
# 9                 950    14973.333333
# 10               1740    15647.666667
# 11               1148     8557.833333
# 12               1538    12572.500000
# 13               1796     7406.333333
# 14                786    12797.416667

# %% [markdown]
# Challenge 10 – Company Report
# Display
# • first five rows
# • last five rows
# • ten random rows
# • dataset information
# • descriptive statistics
# Finally rename
# Target → Customer_Status

# %%
df.head(5)
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0       10001  58.0       49184.0      2139          581        NaN       2
# 1       10002  65.0      162964.0      6197          732    6356.54       1
# 2       10003  56.0       26956.0     37281          503  143203.92       8
# 3       10004  55.0       92926.0       925          463  139627.88       5
# 4       10005  66.0      108236.0      7198          394   75985.46       5
#
#   Geography Gender    Segment Target   NetWorth  AgeAfterRetirement  \
# 0    France   Male        SME   Stay        NaN                78.0
# 1       USA   Male        SME  Churn  169320.54                85.0
# 2    Canada   Male  Corporate   Stay  170159.92                76.0
# 3       NaN   Male     Retail  Churn  232553.88                75.0
# 4        UK  Other  Corporate  Churn  184221.46                86.0
#
#    DoubleCreditScore  IncomePerMonth
# 0               1162     4098.666667
# 1               1464    13580.333333
# 2               1006     2246.333333
# 3                926     7743.833333
# 4                788     9019.666667

# %%
df.tail(5)
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target   NetWorth  \
# 1015       2       USA   Other  Corporate   Stay  233973.03
# 1016       4     India     NaN  Corporate  Churn  179002.07
# 1017       8   Germany  Female     Retail   Stay  135912.09
# 1018       6   Germany   Other  Corporate   Stay        NaN
# 1019      10    Canada   Other        NaN  Churn        NaN
#
#       AgeAfterRetirement  DoubleCreditScore  IncomePerMonth
# 1015                63.0               1288    14468.333333
# 1016                45.0                606     4540.833333
# 1017                69.0               1626     6838.500000
# 1018                58.0               1444             NaN
# 1019                82.0                860     8125.333333

# %%
df.sample(10)
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 146       10147  32.0      143594.0      2140          874   65601.26       9
# 301       10302  20.0      193066.0     27975          316   48133.26       1
# 909       10910  66.0      118506.0      6296          306   81892.13       4
# 156       10157  18.0      113911.0     16093          631    3156.22       4
# 9         10010  22.0      179680.0     42113          475  106827.98       3
# 474       10475  51.0      129994.0      7874          724   29928.46       9
# 490       10491  40.0      140323.0     17014          523   93339.60      10
# 595       10596  24.0      156674.0     42021          580  166974.45       4
# 43        10044  31.0      109884.0     13842          570  101081.81       4
# 900       10901  69.0      168172.0     48245          752   67736.89       1
#
#     Geography  Gender    Segment Target   NetWorth  AgeAfterRetirement  \
# 146       USA   Other     Retail   Stay  209195.26                52.0
# 301     India   Other     Retail  Churn  241199.26                40.0
# 909    Canada    Male        SME  Churn  200398.13                86.0
# 156     India     NaN        SME  Churn  117067.22                38.0
# 9         USA  Female  Corporate  Churn  286507.98                42.0
# 474   Germany   Other     Retail   Stay  159922.46                71.0
# 490   Germany   Other  Corporate   Stay  233662.60                60.0
# 595   Germany   Other        SME   Stay  323648.45                44.0
# 43      India    Male        SME   Stay  210965.81                51.0
# 900    France     NaN     Retail  Churn  235908.89                89.0
#
#      DoubleCreditScore  IncomePerMonth
# 146               1748    11966.166667
# 301                632    16088.833333
# 909                612     9875.500000
# 156               1262     9492.583333
# 9                  950    14973.333333
# 474               1448    10832.833333
# 490               1046    11693.583333
# 595               1160    13056.166667
# 43                1140     9157.000000
# 900               1504    14014.333333

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          1020 non-null   int64
#  1   Age                 970 non-null    float64
#  2   AnnualIncome        967 non-null    float64
#  3   Spending            1020 non-null   int64
#  4   CreditScore         1020 non-null   int64
#  5   Balance             969 non-null    float64
#  6   Tenure              1020 non-null   int64
#  7   Geography           969 non-null    object
#  8   Gender              968 non-null    object
#  9   Segment             969 non-null    object
#  10  Target              1020 non-null   object
#  11  NetWorth            920 non-null    float64
#  12  AgeAfterRetirement  970 non-null    float64
#  13  DoubleCreditScore   1020 non-null   int64
#  14  IncomePerMonth      967 non-null    float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 119.7+ KB

# %%
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#              Balance       Tenure       NetWorth  AgeAfterRetirement  \
# count     969.000000  1020.000000     920.000000          970.000000
# mean    97523.535666     5.261765  209641.594380           64.249485
# std     55796.562543     3.185330   74287.727616           15.521935
# min       547.600000     0.000000   33432.390000           38.000000
# 25%     50077.860000     2.000000  156965.307500           50.250000
# 50%     95100.060000     5.000000  209204.760000           64.000000
# 75%    143947.810000     8.000000  261256.997500           78.000000
# max    199885.880000    10.000000  390628.400000           90.000000
#
#        DoubleCreditScore  IncomePerMonth
# count        1020.000000      967.000000
# mean         1205.319608     9375.494054
# std           353.121379     4358.613545
# min           600.000000     1685.583333
# 25%           881.500000     5512.416667
# 50%          1214.000000     9363.166667
# 75%          1514.500000    13166.708333
# max          1800.000000    16663.916667

# %%
df=df.rename(columns={
    "Target":"Customer_Status"})
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Customer_Status   NetWorth  \
# 0          2    France    Male        SME            Stay        NaN
# 1          1       USA    Male        SME           Churn  169320.54
# 2          8    Canada    Male  Corporate            Stay  170159.92
# 3          5       NaN    Male     Retail           Churn  232553.88
# 4          5        UK   Other  Corporate           Churn  184221.46
# ...      ...       ...     ...        ...             ...        ...
# 1015       2       USA   Other  Corporate            Stay  233973.03
# 1016       4     India     NaN  Corporate           Churn  179002.07
# 1017       8   Germany  Female     Retail            Stay  135912.09
# 1018       6   Germany   Other  Corporate            Stay        NaN
# 1019      10    Canada   Other        NaN           Churn        NaN
#
#       AgeAfterRetirement  DoubleCreditScore  IncomePerMonth
# 0                   78.0               1162     4098.666667
# 1                   85.0               1464    13580.333333
# 2                   76.0               1006     2246.333333
# 3                   75.0                926     7743.833333
# 4                   86.0                788     9019.666667
# ...                  ...                ...             ...
# 1015                63.0               1288    14468.333333
# 1016                45.0                606     4540.833333
# 1017                69.0               1626     6838.500000
# 1018                58.0               1444             NaN
# 1019                82.0                860     8125.333333
#
# [1020 rows x 15 columns]

# %% [markdown]
# Challenge 11 – Missing Value Report
# Create a report showing
# • Total missing values
# • Numerical columns
# • Mean of Balance
# • Median of Age
# • Fill missing values
# • Display information again

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Age                    50
# AnnualIncome           53
# Spending                0
# CreditScore             0
# Balance                51
# Tenure                  0
# Geography              51
# Gender                 52
# Segment                51
# Customer_Status         0
# NetWorth              100
# AgeAfterRetirement     50
# DoubleCreditScore       0
# IncomePerMonth         53
# dtype: int64

# %%
df.select_dtypes(include=['number'])
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure
# 0          10001  58.0       49184.0      2139          581        NaN       2
# 1          10002  65.0      162964.0      6197          732    6356.54       1
# 2          10003  56.0       26956.0     37281          503  143203.92       8
# 3          10004  55.0       92926.0       925          463  139627.88       5
# 4          10005  66.0      108236.0      7198          394   75985.46       5
# ...          ...   ...           ...       ...          ...        ...     ...
# 1015       10450  43.0      173620.0      7121          644   60353.03       2
# 1016       10753  25.0       54490.0     13794          303  124512.07       4
# 1017       10810  49.0       82062.0     47170          813   53850.09       8
# 1018       10267  38.0           NaN     10424          722  138100.05       6
# 1019       10059  62.0       97504.0     36833          430        NaN      10
#
# [1020 rows x 7 columns]

# %%
df['Balance']=df['Balance'].fillna(df['Balance'].mean())
df['Age']=df['Age'].fillna(df['Age'].mean())
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0          10001  58.0       49184.0      2139          581   97523.535666
# 1          10002  65.0      162964.0      6197          732    6356.540000
# 2          10003  56.0       26956.0     37281          503  143203.920000
# 3          10004  55.0       92926.0       925          463  139627.880000
# 4          10005  66.0      108236.0      7198          394   75985.460000
# ...          ...   ...           ...       ...          ...            ...
# 1015       10450  43.0      173620.0      7121          644   60353.030000
# 1016       10753  25.0       54490.0     13794          303  124512.070000
# 1017       10810  49.0       82062.0     47170          813   53850.090000
# 1018       10267  38.0           NaN     10424          722  138100.050000
# 1019       10059  62.0       97504.0     36833          430   97523.535666
#
#       Tenure Geography  Gender    Segment Customer_Status   NetWorth  \
# 0          2    France    Male        SME            Stay        NaN
# 1          1       USA    Male        SME           Churn  169320.54
# 2          8    Canada    Male  Corporate            Stay  170159.92
# 3          5       NaN    Male     Retail           Churn  232553.88
# 4          5        UK   Other  Corporate           Churn  184221.46
# ...      ...       ...     ...        ...             ...        ...
# 1015       2       USA   Other  Corporate            Stay  233973.03
# 1016       4     India     NaN  Corporate           Churn  179002.07
# 1017       8   Germany  Female     Retail            Stay  135912.09
# 1018       6   Germany   Other  Corporate            Stay        NaN
# 1019      10    Canada   Other        NaN           Churn        NaN
#
#       AgeAfterRetirement  DoubleCreditScore  IncomePerMonth
# 0                   78.0               1162     4098.666667
# 1                   85.0               1464    13580.333333
# 2                   76.0               1006     2246.333333
# 3                   75.0                926     7743.833333
# 4                   86.0                788     9019.666667
# ...                  ...                ...             ...
# 1015                63.0               1288    14468.333333
# 1016                45.0                606     4540.833333
# 1017                69.0               1626     6838.500000
# 1018                58.0               1444             NaN
# 1019                82.0                860     8125.333333
#
# [1020 rows x 15 columns]

# %%
numeric_cols=df.select_dtypes(include="number").columns
df[numeric_cols]=df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
df[numeric_cols]
# Out:
#       CustomerID   Age   AnnualIncome  Spending  CreditScore        Balance  \
# 0          10001  58.0   49184.000000      2139          581   97523.535666
# 1          10002  65.0  162964.000000      6197          732    6356.540000
# 2          10003  56.0   26956.000000     37281          503  143203.920000
# 3          10004  55.0   92926.000000       925          463  139627.880000
# 4          10005  66.0  108236.000000      7198          394   75985.460000
# ...          ...   ...            ...       ...          ...            ...
# 1015       10450  43.0  173620.000000      7121          644   60353.030000
# 1016       10753  25.0   54490.000000     13794          303  124512.070000
# 1017       10810  49.0   82062.000000     47170          813   53850.090000
# 1018       10267  38.0  112505.928645     10424          722  138100.050000
# 1019       10059  62.0   97504.000000     36833          430   97523.535666
#
#       Tenure
# 0          2
# 1          1
# 2          8
# 3          5
# 4          5
# ...      ...
# 1015       2
# 1016       4
# 1017       8
# 1018       6
# 1019      10
#
# [1020 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          1020 non-null   int64
#  1   Age                 1020 non-null   float64
#  2   AnnualIncome        967 non-null    float64
#  3   Spending            1020 non-null   int64
#  4   CreditScore         1020 non-null   int64
#  5   Balance             1020 non-null   float64
#  6   Tenure              1020 non-null   int64
#  7   Geography           969 non-null    object
#  8   Gender              968 non-null    object
#  9   Segment             969 non-null    object
#  10  Customer_Status     1020 non-null   object
#  11  NetWorth            920 non-null    float64
#  12  AgeAfterRetirement  970 non-null    float64
#  13  DoubleCreditScore   1020 non-null   int64
#  14  IncomePerMonth      967 non-null    float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 119.7+ KB

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")

# %% [markdown]
# Challenge 12 – Customer Classification
# Count
# Stay
#
# Churn
# Then
# Rename
# Target → Customer_Class
# Convert it into string.

# %%
df["Target"].value_counts()
# Out:
# Target
# Churn    515
# Stay     505
# Name: count, dtype: int64

# %%
df.rename(columns={
    'Target':'Customer_Class'
},inplace=True)
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Customer_Class
# 0          2    France    Male        SME           Stay
# 1          1       USA    Male        SME          Churn
# 2          8    Canada    Male  Corporate           Stay
# 3          5       NaN    Male     Retail          Churn
# 4          5        UK   Other  Corporate          Churn
# ...      ...       ...     ...        ...            ...
# 1015       2       USA   Other  Corporate           Stay
# 1016       4     India     NaN  Corporate          Churn
# 1017       8   Germany  Female     Retail           Stay
# 1018       6   Germany   Other  Corporate           Stay
# 1019      10    Canada   Other        NaN          Churn
#
# [1020 rows x 11 columns]

# %%
df=df.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      1020 non-null   object
#  1   Age             1020 non-null   object
#  2   AnnualIncome    1020 non-null   object
#  3   Spending        1020 non-null   object
#  4   CreditScore     1020 non-null   object
#  5   Balance         1020 non-null   object
#  6   Tenure          1020 non-null   object
#  7   Geography       1020 non-null   object
#  8   Gender          1020 non-null   object
#  9   Segment         1020 non-null   object
#  10  Customer_Class  1020 non-null   object
# dtypes: object(11)
# memory usage: 87.8+ KB

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")

# %% [markdown]
# Challenge 13 – Sales Department
# Rename
# Balance → AccountBalance
# AnnualIncome → Salary
# CreditScore → Score
# Add prefix
# Sales_
# Then
# Display
# sample(20)

# %%
df=df.rename(columns={
    "Balance":"AccountBalance",
    "AnnualIncome":"Salary",
    "CreditScore":"Score"})
df
# Out:
#       CustomerID   Age    Salary  Spending  Score  AccountBalance  Tenure  \
# 0          10001  58.0   49184.0      2139    581             NaN       2
# 1          10002  65.0  162964.0      6197    732         6356.54       1
# 2          10003  56.0   26956.0     37281    503       143203.92       8
# 3          10004  55.0   92926.0       925    463       139627.88       5
# 4          10005  66.0  108236.0      7198    394        75985.46       5
# ...          ...   ...       ...       ...    ...             ...     ...
# 1015       10450  43.0  173620.0      7121    644        60353.03       2
# 1016       10753  25.0   54490.0     13794    303       124512.07       4
# 1017       10810  49.0   82062.0     47170    813        53850.09       8
# 1018       10267  38.0       NaN     10424    722       138100.05       6
# 1019       10059  62.0   97504.0     36833    430             NaN      10
#
#      Geography  Gender    Segment Target
# 0       France    Male        SME   Stay
# 1          USA    Male        SME  Churn
# 2       Canada    Male  Corporate   Stay
# 3          NaN    Male     Retail  Churn
# 4           UK   Other  Corporate  Churn
# ...        ...     ...        ...    ...
# 1015       USA   Other  Corporate   Stay
# 1016     India     NaN  Corporate  Churn
# 1017   Germany  Female     Retail   Stay
# 1018   Germany   Other  Corporate   Stay
# 1019    Canada   Other        NaN  Churn
#
# [1020 rows x 11 columns]

# %%
df=df.add_prefix("Sales_")
df
# Out:
#       Sales_CustomerID  Sales_Age  Sales_Salary  Sales_Spending  Sales_Score  \
# 0                10001       58.0       49184.0            2139          581
# 1                10002       65.0      162964.0            6197          732
# 2                10003       56.0       26956.0           37281          503
# 3                10004       55.0       92926.0             925          463
# 4                10005       66.0      108236.0            7198          394
# ...                ...        ...           ...             ...          ...
# 1015             10450       43.0      173620.0            7121          644
# 1016             10753       25.0       54490.0           13794          303
# 1017             10810       49.0       82062.0           47170          813
# 1018             10267       38.0           NaN           10424          722
# 1019             10059       62.0       97504.0           36833          430
#
#       Sales_AccountBalance  Sales_Tenure Sales_Geography Sales_Gender  \
# 0                      NaN             2          France         Male
# 1                  6356.54             1             USA         Male
# 2                143203.92             8          Canada         Male
# 3                139627.88             5             NaN         Male
# 4                 75985.46             5              UK        Other
# ...                    ...           ...             ...          ...
# 1015              60353.03             2             USA        Other
# 1016             124512.07             4           India          NaN
# 1017              53850.09             8         Germany       Female
# 1018             138100.05             6         Germany        Other
# 1019                   NaN            10          Canada        Other
#
#      Sales_Segment Sales_Target
# 0              SME         Stay
# 1              SME        Churn
# 2        Corporate         Stay
# 3           Retail        Churn
# 4        Corporate        Churn
# ...            ...          ...
# 1015     Corporate         Stay
# 1016     Corporate        Churn
# 1017        Retail         Stay
# 1018     Corporate         Stay
# 1019           NaN        Churn
#
# [1020 rows x 11 columns]

# %%
df.sample(20)
# Out:
#       Sales_CustomerID  Sales_Age  Sales_Salary  Sales_Spending  Sales_Score  \
# 835              10836  49.000000       72604.0           40496          702
# 585              10586  39.000000      145817.0           30833          756
# 1007             10756  53.000000       74430.0            3705          489
# 282              10283  18.000000      108371.0           19834          881
# 774              10775  20.000000       91171.0           27623          388
# 307              10308  68.000000      157484.0           21388          726
# 860              10861  66.000000      161485.0           33762          524
# 1008             10417  70.000000       40417.0           37956          681
# 961              10962  44.249485      171569.0            6708          644
# 483              10484  21.000000           NaN            2667          767
# 543              10544  51.000000       32732.0           36756          743
# 868              10869  26.000000      139993.0           47674          498
# 346              10347  69.000000      106387.0           29350          642
# 187              10188  49.000000      141622.0           49943          877
# 839              10840  50.000000           NaN           31835          746
# 368              10369  38.000000       50896.0           16135          612
# 30               10031  46.000000      164264.0            6916          351
# 904              10905  50.000000      123395.0           13243          802
# 661              10662  46.000000      100705.0           24471          722
# 264              10265  32.000000       33462.0           38741          791
#
#       Sales_AccountBalance  Sales_Tenure Sales_Geography Sales_Gender  \
# 835           35688.430000             7             NaN         Male
# 585           71748.320000             4          Canada        Other
# 1007          29651.230000            10              UK         Male
# 282          134880.230000             3             USA        Other
# 774           99410.890000             3              UK       Female
# 307           81651.840000             4          Canada         Male
# 860           92843.200000            10          France         Male
# 1008          23880.190000            10           India         Male
# 961           54672.990000             9         Germany       Female
# 483           10111.860000             5          France         Male
# 543          167763.220000             7         Germany         Male
# 868          126404.220000             4             NaN       Female
# 346           97523.535666            10         Germany         Male
# 187           97523.535666             7          France        Other
# 839           80782.550000             1         Germany         Male
# 368           23389.780000             5          France         Male
# 30           130428.980000             8           India         Male
# 904           63551.560000             9         Germany         Male
# 661           51961.410000             4           India         Male
# 264           34102.410000            10          France        Other
#
#      Sales_Segment Sales_Customer_Status  Sales_NetWorth  \
# 835            SME                  Stay       108292.43
# 585         Retail                  Stay       217565.32
# 1007        Retail                 Churn       104081.23
# 282            SME                  Stay       243251.23
# 774      Corporate                 Churn       190581.89
# 307            SME                  Stay       239135.84
# 860      Corporate                  Stay       254328.20
# 1008        Retail                  Stay        64297.19
# 961      Corporate                  Stay       226241.99
# 483      Corporate                 Churn             NaN
# 543            SME                  Stay       200495.22
# 868         Retail                 Churn       266397.22
# 346      Corporate                  Stay             NaN
# 187            SME                  Stay             NaN
# 839         Retail                 Churn             NaN
# 368            SME                  Stay        74285.78
# 30             NaN                 Churn       294692.98
# 904            SME                  Stay       186946.56
# 661            SME                  Stay       152666.41
# 264      Corporate                  Stay        67564.41
#
#       Sales_AgeAfterRetirement  Sales_DoubleCreditScore  Sales_IncomePerMonth
# 835                       69.0                     1404           6050.333333
# 585                       59.0                     1512          12151.416667
# 1007                      73.0                      978           6202.500000
# 282                       38.0                     1762           9030.916667
# 774                       40.0                      776           7597.583333
# 307                       88.0                     1452          13123.666667
# 860                       86.0                     1048          13457.083333
# 1008                      90.0                     1362           3368.083333
# 961                        NaN                     1288          14297.416667
# 483                       41.0                     1534                   NaN
# 543                       71.0                     1486           2727.666667
# 868                       46.0                      996          11666.083333
# 346                       89.0                     1284           8865.583333
# 187                       69.0                     1754          11801.833333
# 839                       70.0                     1492                   NaN
# 368                       58.0                     1224           4241.333333
# 30                        66.0                      702          13688.666667
# 904                       70.0                     1604          10282.916667
# 661                       66.0                     1444           8392.083333
# 264                       52.0                     1582           2788.500000

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")

# %% [markdown]
# Challenge 14 – Interview Challenge
# Without creating another DataFrame,
# perform
# • remove duplicates
# • rename Target
# • fill missing values
# • convert Balance to float
# • display summary

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Sales_CustomerID  Sales_Age  Sales_Salary  Sales_Spending  Sales_Score  \
# 0               10001       58.0       49184.0            2139          581
# 1               10002       65.0      162964.0            6197          732
# 2               10003       56.0       26956.0           37281          503
# 3               10004       55.0       92926.0             925          463
# 4               10005       66.0      108236.0            7198          394
# ..                ...        ...           ...             ...          ...
# 995             10996       34.0       81731.0           40980          761
# 996             10997       47.0       42475.0            1176          780
# 997             10998       31.0      120531.0           46929          733
# 998             10999       21.0       33661.0           22314          540
# 999             11000       63.0       31930.0             851          559
#
#      Sales_AccountBalance  Sales_Tenure Sales_Geography Sales_Gender  \
# 0                     NaN             2          France         Male
# 1                 6356.54             1             USA         Male
# 2               143203.92             8          Canada         Male
# 3               139627.88             5             NaN         Male
# 4                75985.46             5              UK        Other
# ..                    ...           ...             ...          ...
# 995             181465.65             5         Germany        Other
# 996              26640.99             5          France       Female
# 997             147220.82             4           India         Male
# 998              94186.48             5             NaN        Other
# 999             100908.40             6              UK       Female
#
#     Sales_Segment Sales_Target
# 0             SME         Stay
# 1             SME        Churn
# 2       Corporate         Stay
# 3          Retail        Churn
# 4       Corporate        Churn
# ..            ...          ...
# 995           SME         Stay
# 996           SME         Stay
# 997           SME         Stay
# 998           SME         Stay
# 999           NaN         Stay
#
# [1000 rows x 11 columns]

# %%
df.rename(columns={
    "Target": "CustomerID"
    }, inplace=True)
df
# Out:
#      Sales_CustomerID  Sales_Age  Sales_Salary  Sales_Spending  Sales_Score  \
# 0               10001       58.0       49184.0            2139          581
# 1               10002       65.0      162964.0            6197          732
# 2               10003       56.0       26956.0           37281          503
# 3               10004       55.0       92926.0             925          463
# 4               10005       66.0      108236.0            7198          394
# ..                ...        ...           ...             ...          ...
# 995             10996       34.0       81731.0           40980          761
# 996             10997       47.0       42475.0            1176          780
# 997             10998       31.0      120531.0           46929          733
# 998             10999       21.0       33661.0           22314          540
# 999             11000       63.0       31930.0             851          559
#
#      Sales_AccountBalance  Sales_Tenure Sales_Geography Sales_Gender  \
# 0                     NaN             2          France         Male
# 1                 6356.54             1             USA         Male
# 2               143203.92             8          Canada         Male
# 3               139627.88             5             NaN         Male
# 4                75985.46             5              UK        Other
# ..                    ...           ...             ...          ...
# 995             181465.65             5         Germany        Other
# 996              26640.99             5          France       Female
# 997             147220.82             4           India         Male
# 998              94186.48             5             NaN        Other
# 999             100908.40             6              UK       Female
#
#     Sales_Segment Sales_Target
# 0             SME         Stay
# 1             SME        Churn
# 2       Corporate         Stay
# 3          Retail        Churn
# 4       Corporate        Churn
# ..            ...          ...
# 995           SME         Stay
# 996           SME         Stay
# 997           SME         Stay
# 998           SME         Stay
# 999           NaN         Stay
#
# [1000 rows x 11 columns]

# %%
numeric_cols=df.select_dtypes(include="number").columns
df[numeric_cols]=df[numeric_cols].fillna(df[numeric_cols].mean())

# %%
df[numeric_cols]
# Out:
#      Sales_CustomerID  Sales_Age  Sales_Salary  Sales_Spending  Sales_Score  \
# 0               10001       58.0       49184.0            2139          581
# 1               10002       65.0      162964.0            6197          732
# 2               10003       56.0       26956.0           37281          503
# 3               10004       55.0       92926.0             925          463
# 4               10005       66.0      108236.0            7198          394
# ..                ...        ...           ...             ...          ...
# 995             10996       34.0       81731.0           40980          761
# 996             10997       47.0       42475.0            1176          780
# 997             10998       31.0      120531.0           46929          733
# 998             10999       21.0       33661.0           22314          540
# 999             11000       63.0       31930.0             851          559
#
#      Sales_AccountBalance  Sales_Tenure
# 0            97557.565779             2
# 1             6356.540000             1
# 2           143203.920000             8
# 3           139627.880000             5
# 4            75985.460000             5
# ..                    ...           ...
# 995         181465.650000             5
# 996          26640.990000             5
# 997         147220.820000             4
# 998          94186.480000             5
# 999         100908.400000             6
#
# [1000 rows x 7 columns]

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'AnnualIncome', 'Spending', 'CreditScore',
#        'Balance', 'Tenure', 'Geography', 'Gender', 'Segment', 'Target'],
#       dtype='object')

# %%
df["Balance"]=df["Balance"].astype(str)

# %%
df["Balance"]
# Out:
# 0             nan
# 1         6356.54
# 2       143203.92
# 3       139627.88
# 4        75985.46
#           ...
# 1015     60353.03
# 1016    124512.07
# 1017     53850.09
# 1018    138100.05
# 1019          nan
# Name: Balance, Length: 1020, dtype: object

# %%
df.describe()
# Out:
#          CustomerID         Age   AnnualIncome      Spending  CreditScore  \
# count   1020.000000  970.000000     967.000000   1020.000000  1020.000000
# mean   10501.599020   44.249485  112505.928645  25232.615686   602.659804
# std      288.022115   15.521935   52303.362541  14219.393105   176.560690
# min    10001.000000   18.000000   20227.000000    537.000000   300.000000
# 25%    10252.750000   30.250000   66149.000000  13134.750000   440.750000
# 50%    10502.500000   44.000000  112358.000000  24798.000000   607.000000
# 75%    10752.250000   58.000000  158000.500000  37956.000000   757.250000
# max    11000.000000   70.000000  199967.000000  49995.000000   900.000000
#
#             Tenure
# count  1020.000000
# mean      5.261765
# std       3.185330
# min       0.000000
# 25%       2.000000
# 50%       5.000000
# 75%       8.000000
# max      10.000000

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# 1          1       USA    Male        SME  Churn
# 2          8    Canada    Male  Corporate   Stay
# 3          5       NaN    Male     Retail  Churn
# 4          5        UK   Other  Corporate  Churn
# ...      ...       ...     ...        ...    ...
# 1015       2       USA   Other  Corporate   Stay
# 1016       4     India     NaN  Corporate  Churn
# 1017       8   Germany  Female     Retail   Stay
# 1018       6   Germany   Other  Corporate   Stay
# 1019      10    Canada   Other        NaN  Churn
#
# [1020 rows x 11 columns]

# %% [markdown]
# Challenge 15 – Data Engineer Task
# Load the dataset.
# Create another DataFrame containing only numeric columns.
# Drop
# CustomerID
# Target
# Display summary.

# %%
new_df = df.select_dtypes(include="number")

# %%
new_df.drop(columns=["CustomerID", "Target"], inplace=True, errors="ignore")

# %%
print(new_df.describe())
# Out:
#               Age   AnnualIncome      Spending  CreditScore        Balance  \
# count  970.000000     967.000000   1020.000000  1020.000000     969.000000
# mean    44.249485  112505.928645  25232.615686   602.659804   97523.535666
# std     15.521935   52303.362541  14219.393105   176.560690   55796.562543
# min     18.000000   20227.000000    537.000000   300.000000     547.600000
# 25%     30.250000   66149.000000  13134.750000   440.750000   50077.860000
# 50%     44.000000  112358.000000  24798.000000   607.000000   95100.060000
# 75%     58.000000  158000.500000  37956.000000   757.250000  143947.810000
# max     70.000000  199967.000000  49995.000000   900.000000  199885.880000
#
#             Tenure
# count  1020.000000
# mean      5.261765
# std       3.185330
# min       0.000000
# 25%       2.000000
# 50%       5.000000
# 75%       8.000000
# max      10.000000

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# 1          1       USA    Male        SME  Churn
# 2          8    Canada    Male  Corporate   Stay
# 3          5       NaN    Male     Retail  Churn
# 4          5        UK   Other  Corporate  Churn
# ...      ...       ...     ...        ...    ...
# 1015       2       USA   Other  Corporate   Stay
# 1016       4     India     NaN  Corporate  Churn
# 1017       8   Germany  Female     Retail   Stay
# 1018       6   Germany   Other  Corporate   Stay
# 1019      10    Canada   Other        NaN  Churn
#
# [1020 rows x 11 columns]

# %% [markdown]
# Challenge 16 – Mixed Cleaning
# Perform
# drop_duplicates()
# fillna()
# astype()
# rename()
# head()
# info()
# using only one DataFrame variable.

# %%
df.drop_duplicates(inplace=True)
df["Age"] = df["Age"].fillna(df["Age"].median())
df["Balance"] = df["Balance"].fillna(df["Balance"].mean())
df["Age"] = df["Age"].astype(int)
df["Balance"] = df["Balance"].astype(float)
df.rename(columns={"Target": "Output"}, inplace=True)
print(df.head())
df.info()
# Out:
#    CustomerID  Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001   58       49184.0      2139          581   97557.565779
# 1       10002   65      162964.0      6197          732    6356.540000
# 2       10003   56       26956.0     37281          503  143203.920000
# 3       10004   55       92926.0       925          463  139627.880000
# 4       10005   66      108236.0      7198          394   75985.460000
#
#    Tenure Geography Gender    Segment Output
# 0       2    France   Male        SME   Stay
# 1       1       USA   Male        SME  Churn
# 2       8    Canada   Male  Corporate   Stay
# 3       5       NaN   Male     Retail  Churn
# 4       5        UK  Other  Corporate  Churn
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    1000 non-null   int64
#  1   Age           1000 non-null   int32
#  2   AnnualIncome  950 non-null    float64
#  3   Spending      1000 non-null   int64
#  4   CreditScore   1000 non-null   int64
#  5   Balance       1000 non-null   float64
#  6   Tenure        1000 non-null   int64
#  7   Geography     950 non-null    object
#  8   Gender        950 non-null    object
#  9   Segment       950 non-null    object
#  10  Output        1000 non-null   object
# dtypes: float64(2), int32(1), int64(4), object(4)
# memory usage: 89.8+ KB

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# 1          1       USA    Male        SME  Churn
# 2          8    Canada    Male  Corporate   Stay
# 3          5       NaN    Male     Retail  Churn
# 4          5        UK   Other  Corporate  Churn
# ...      ...       ...     ...        ...    ...
# 1015       2       USA   Other  Corporate   Stay
# 1016       4     India     NaN  Corporate  Churn
# 1017       8   Germany  Female     Retail   Stay
# 1018       6   Germany   Other  Corporate   Stay
# 1019      10    Canada   Other        NaN  Churn
#
# [1020 rows x 11 columns]

# %% [markdown]
# Challenge 17 – Real Company Dataset
# Manager asks
# Remove duplicate records
#
# Fill missing values
# Rename all business columns
# Add company prefix
# Display summary
# Display target counts

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  Tenure  \
# 0         10001  58.0       49184.0      2139          581        NaN       2
# 1         10002  65.0      162964.0      6197          732    6356.54       1
# 2         10003  56.0       26956.0     37281          503  143203.92       8
# 3         10004  55.0       92926.0       925          463  139627.88       5
# 4         10005  66.0      108236.0      7198          394   75985.46       5
# ..          ...   ...           ...       ...          ...        ...     ...
# 995       10996  34.0       81731.0     40980          761  181465.65       5
# 996       10997  47.0       42475.0      1176          780   26640.99       5
# 997       10998  31.0      120531.0     46929          733  147220.82       4
# 998       10999  21.0       33661.0     22314          540   94186.48       5
# 999       11000  63.0       31930.0       851          559  100908.40       6
#
#     Geography  Gender    Segment Target
# 0      France    Male        SME   Stay
# 1         USA    Male        SME  Churn
# 2      Canada    Male  Corporate   Stay
# 3         NaN    Male     Retail  Churn
# 4          UK   Other  Corporate  Churn
# ..        ...     ...        ...    ...
# 995   Germany   Other        SME   Stay
# 996    France  Female        SME   Stay
# 997     India    Male        SME   Stay
# 998       NaN   Other        SME   Stay
# 999        UK  Female        NaN   Stay
#
# [1000 rows x 11 columns]

# %%
numeric_cols = df.select_dtypes(include="number").columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())
df
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0         10001  58.0       49184.0      2139          581   97557.565779
# 1         10002  65.0      162964.0      6197          732    6356.540000
# 2         10003  56.0       26956.0     37281          503  143203.920000
# 3         10004  55.0       92926.0       925          463  139627.880000
# 4         10005  66.0      108236.0      7198          394   75985.460000
# ..          ...   ...           ...       ...          ...            ...
# 995       10996  34.0       81731.0     40980          761  181465.650000
# 996       10997  47.0       42475.0      1176          780   26640.990000
# 997       10998  31.0      120531.0     46929          733  147220.820000
# 998       10999  21.0       33661.0     22314          540   94186.480000
# 999       11000  63.0       31930.0       851          559  100908.400000
#
#      Tenure Geography  Gender    Segment Target
# 0         2    France    Male        SME   Stay
# 1         1       USA    Male        SME  Churn
# 2         8    Canada    Male  Corporate   Stay
# 3         5       NaN    Male     Retail  Churn
# 4         5        UK   Other  Corporate  Churn
# ..      ...       ...     ...        ...    ...
# 995       5   Germany   Other        SME   Stay
# 996       5    France  Female        SME   Stay
# 997       4     India    Male        SME   Stay
# 998       5       NaN   Other        SME   Stay
# 999       6        UK  Female        NaN   Stay
#
# [1000 rows x 11 columns]

# %%
categorical_cols = df.select_dtypes(include="object").columns
for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])
df
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0         10001  58.0       49184.0      2139          581   97557.565779
# 1         10002  65.0      162964.0      6197          732    6356.540000
# 2         10003  56.0       26956.0     37281          503  143203.920000
# 3         10004  55.0       92926.0       925          463  139627.880000
# 4         10005  66.0      108236.0      7198          394   75985.460000
# ..          ...   ...           ...       ...          ...            ...
# 995       10996  34.0       81731.0     40980          761  181465.650000
# 996       10997  47.0       42475.0      1176          780   26640.990000
# 997       10998  31.0      120531.0     46929          733  147220.820000
# 998       10999  21.0       33661.0     22314          540   94186.480000
# 999       11000  63.0       31930.0       851          559  100908.400000
#
#      Tenure Geography  Gender    Segment Target
# 0         2    France    Male        SME   Stay
# 1         1       USA    Male        SME  Churn
# 2         8    Canada    Male  Corporate   Stay
# 3         5     India    Male     Retail  Churn
# 4         5        UK   Other  Corporate  Churn
# ..      ...       ...     ...        ...    ...
# 995       5   Germany   Other        SME   Stay
# 996       5    France  Female        SME   Stay
# 997       4     India    Male        SME   Stay
# 998       5     India   Other        SME   Stay
# 999       6        UK  Female        SME   Stay
#
# [1000 rows x 11 columns]

# %%
df.rename(columns={"Target": "Customer_Status"}, inplace=True)
df
# Out:
#      CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0         10001  58.0       49184.0      2139          581   97557.565779
# 1         10002  65.0      162964.0      6197          732    6356.540000
# 2         10003  56.0       26956.0     37281          503  143203.920000
# 3         10004  55.0       92926.0       925          463  139627.880000
# 4         10005  66.0      108236.0      7198          394   75985.460000
# ..          ...   ...           ...       ...          ...            ...
# 995       10996  34.0       81731.0     40980          761  181465.650000
# 996       10997  47.0       42475.0      1176          780   26640.990000
# 997       10998  31.0      120531.0     46929          733  147220.820000
# 998       10999  21.0       33661.0     22314          540   94186.480000
# 999       11000  63.0       31930.0       851          559  100908.400000
#
#      Tenure Geography  Gender    Segment Customer_Status
# 0         2    France    Male        SME            Stay
# 1         1       USA    Male        SME           Churn
# 2         8    Canada    Male  Corporate            Stay
# 3         5     India    Male     Retail           Churn
# 4         5        UK   Other  Corporate           Churn
# ..      ...       ...     ...        ...             ...
# 995       5   Germany   Other        SME            Stay
# 996       5    France  Female        SME            Stay
# 997       4     India    Male        SME            Stay
# 998       5     India   Other        SME            Stay
# 999       6        UK  Female        SME            Stay
#
# [1000 rows x 11 columns]

# %%
df = df.add_prefix("Company_")
print(df.describe())
print(df["Company_Customer_Status"].value_counts())
# Out:
#        Company_CustomerID  Company_Age  Company_AnnualIncome  \
# count         1000.000000  1000.000000           1000.000000
# mean         10500.500000    44.212632         112458.303158
# std            288.819436    15.130763          51081.475249
# min          10001.000000    18.000000          20227.000000
# 25%          10250.750000    31.000000          68437.250000
# 50%          10500.500000    44.212632         112458.303158
# 75%          10750.250000    57.000000         155570.750000
# max          11000.000000    70.000000         199967.000000
#
#        Company_Spending  Company_CreditScore  Company_Balance  Company_Tenure
# count       1000.000000          1000.000000      1000.000000     1000.000000
# mean       25285.558000           603.088000     97557.565779        5.241000
# std        14211.735656           176.605486     54430.062006        3.179155
# min          537.000000           300.000000       547.600000        0.000000
# 25%        13213.000000           441.000000     52074.240000        2.000000
# 50%        24901.000000           606.500000     97557.565779        5.000000
# 75%        37960.250000           758.250000    142297.910000        8.000000
# max        49995.000000           900.000000    199885.880000       10.000000
# Company_Customer_Status
# Churn    506
# Stay     494
# Name: count, dtype: int64

# %% [markdown]
# Challenge 18 – Customer Summary
# Generate
# Mean Balance
# Median Balance
# Mean Age
# Median AnnualIncome
#
# Then
# fill missing values using these statistics.

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# 1          1       USA    Male        SME  Churn
# 2          8    Canada    Male  Corporate   Stay
# 3          5       NaN    Male     Retail  Churn
# 4          5        UK   Other  Corporate  Churn
# ...      ...       ...     ...        ...    ...
# 1015       2       USA   Other  Corporate   Stay
# 1016       4     India     NaN  Corporate  Churn
# 1017       8   Germany  Female     Retail   Stay
# 1018       6   Germany   Other  Corporate   Stay
# 1019      10    Canada   Other        NaN  Churn
#
# [1020 rows x 11 columns]

# %%
mean_balance = df["Balance"].mean()
median_balance = df["Balance"].median()
mean_age = df["Age"].mean()
median_income = df["AnnualIncome"].median()
print(mean_balance)
print(median_balance)
print(mean_age)
print(median_income)
df["Balance"] = df["Balance"].fillna(mean_balance)
df["Age"] = df["Age"].fillna(mean_age)
df["AnnualIncome"] = df["AnnualIncome"].fillna(median_income)
print(df.isnull().sum())
# Out:
# 97523.53566563467
# 95100.06
# 44.24948453608248
# 112358.0
# CustomerID       0
# Age              0
# AnnualIncome     0
# Spending         0
# CreditScore      0
# Balance          0
# Tenure           0
# Geography       51
# Gender          52
# Segment         51
# Target           0
# dtype: int64

# %% [markdown]
# Challenge 19 – Transformation Challenge
# Create
# Income_in_Lakhs
# Balance_in_Lakhs
#
# SeniorCitizen
# HighCreditScore
# where
# SeniorCitizen = Age + 0
# HighCreditScore = CreditScore * 1
# (No conditional statements.)

# %%
df["Income_in_Lakhs"] = df["AnnualIncome"] / 100000
df["Balance_in_Lakhs"] = df["Balance"] / 100000
df["SeniorCitizen"] = df["Age"] + 0
df["HighCreditScore"] = df["CreditScore"] * 1
df.head(10)
# Out:
#    CustomerID   Age  AnnualIncome  Spending  CreditScore        Balance  \
# 0       10001  58.0       49184.0      2139          581   97523.535666
# 1       10002  65.0      162964.0      6197          732    6356.540000
# 2       10003  56.0       26956.0     37281          503  143203.920000
# 3       10004  55.0       92926.0       925          463  139627.880000
# 4       10005  66.0      108236.0      7198          394   75985.460000
# 5       10006  69.0       31390.0     48323          770  107245.620000
# 6       10007  58.0      182141.0     24200          891   38457.720000
# 7       10008  67.0       95861.0      5729          538  173296.730000
# 8       10009  41.0       62638.0     24760          663   41901.410000
# 9       10010  22.0      179680.0     42113          475  106827.980000
#
#    Tenure Geography  Gender    Segment Target  Income_in_Lakhs  \
# 0       2    France    Male        SME   Stay          0.49184
# 1       1       USA    Male        SME  Churn          1.62964
# 2       8    Canada    Male  Corporate   Stay          0.26956
# 3       5       NaN    Male     Retail  Churn          0.92926
# 4       5        UK   Other  Corporate  Churn          1.08236
# 5       6     India   Other  Corporate   Stay          0.31390
# 6       1     India   Other     Retail  Churn          1.82141
# 7       6        UK  Female        SME   Stay          0.95861
# 8       4    France   Other        SME   Stay          0.62638
# 9       3       USA  Female  Corporate  Churn          1.79680
#
#    Balance_in_Lakhs  SeniorCitizen  HighCreditScore
# 0          0.975235           58.0              581
# 1          0.063565           65.0              732
# 2          1.432039           56.0              503
# 3          1.396279           55.0              463
# 4          0.759855           66.0              394
# 5          1.072456           69.0              770
# 6          0.384577           58.0              891
# 7          1.732967           67.0              538
# 8          0.419014           41.0              663
# 9          1.068280           22.0              475

# %% [markdown]
# Challenge 20 – Final Interview Project
# Your manager gives you a dirty customer dataset.
# Prepare the final dataset.
# Requirements
# Load dataset
# Check information
# Find missing values
# Remove duplicates
# Rename
# CustomerID
# AnnualIncome
# CreditScore
# Target
# Convert
# Age
# AnnualIncome
# Balance
#
# Fill missing values
# Remove
# Segment
# CustomerID
# Create new columns
# TotalMoney = Balance + AnnualIncome
# AgeAfter5Years = Age + 5
# MonthlyIncome = AnnualIncome / 12
# CreditScoreDouble = CreditScore * 2Display
# • Head
# • Tail
# • Sample
# • Describe
# • Target counts
# • Final information

# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\harit\\Downloads\\Task_dataset - Task_dataset.csv")
df
# Out:
#       CustomerID   Age  AnnualIncome  Spending  CreditScore    Balance  \
# 0          10001  58.0       49184.0      2139          581        NaN
# 1          10002  65.0      162964.0      6197          732    6356.54
# 2          10003  56.0       26956.0     37281          503  143203.92
# 3          10004  55.0       92926.0       925          463  139627.88
# 4          10005  66.0      108236.0      7198          394   75985.46
# ...          ...   ...           ...       ...          ...        ...
# 1015       10450  43.0      173620.0      7121          644   60353.03
# 1016       10753  25.0       54490.0     13794          303  124512.07
# 1017       10810  49.0       82062.0     47170          813   53850.09
# 1018       10267  38.0           NaN     10424          722  138100.05
# 1019       10059  62.0       97504.0     36833          430        NaN
#
#       Tenure Geography  Gender    Segment Target
# 0          2    France    Male        SME   Stay
# 1          1       USA    Male        SME  Churn
# 2          8    Canada    Male  Corporate   Stay
# 3          5       NaN    Male     Retail  Churn
# 4          5        UK   Other  Corporate  Churn
# ...      ...       ...     ...        ...    ...
# 1015       2       USA   Other  Corporate   Stay
# 1016       4     India     NaN  Corporate  Churn
# 1017       8   Germany  Female     Retail   Stay
# 1018       6   Germany   Other  Corporate   Stay
# 1019      10    Canada   Other        NaN  Churn
#
# [1020 rows x 11 columns]

# %%
df.info()
print(df.isnull().sum())
df.drop_duplicates(inplace=True)
df.rename(columns={
    "CustomerID": "Customer_ID",
    "AnnualIncome": "Income",
    "CreditScore": "Credit_Score",
    "Target": "Customer_Status"
}, inplace=True)
df["Age"] = df["Age"].fillna(df["Age"].median()).astype(int)
df["Income"] = df["Income"].astype(float)
df["Balance"] = df["Balance"].astype(float)
df["Income"] = df["Income"].fillna(df["Income"].median())
df["Balance"] = df["Balance"].fillna(df["Balance"].mean())
df.drop(columns=["Segment", "Customer_ID"], inplace=True)
df["TotalMoney"] = df["Balance"] + df["Income"]
df["AgeAfter5Years"] = df["Age"] + 5
df["MonthlyIncome"] = df["Income"] / 12
df["CreditScoreDouble"] = df["Credit_Score"] * 2
print("First 5 Rows:")
print(df.head())
print("Last 5 Rows:")
print(df.tail())
print("Random Sample:")
print(df.sample(10))
print("Statistical Summary:")
print(df.describe())
print("Customer Status Counts:")
print(df["Customer_Status"].value_counts())
print("Final Dataset Information:")
df.info()
