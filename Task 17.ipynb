# %% [markdown]
# # Encapsulation

# %% [markdown]
# # 1

# %%
class BankAccount:
    def __init__(self,balance):
        self.__balance=balance
    def get_balance(self):
        return self.__balance
    def deposite_set_balance(self,amount):
        if amount>0:
            self.__balance+=amount
            return self.__balance
        else:
            print("Amount must be greater than 0")
    def withdraw_set_balance(self,amount):
        if amount>0:
            self.__balance-=0
            return self.__balance
        else:
            print("Insufficient amount")
B=BankAccount(6000)
B.deposite_set_balance(2000)
B.withdraw_set_balance(1500)
# Out:
# 8000

# %% [markdown]
# # 2

# %%
class Student:
    def __init__(self,marks):
        self.__marks=marks
    def get_marks(self):
        return self.__marks
    def set_marks(self,marks):
        if marks>0:
            if marks>=0 and marks<=100:
                return self.__marks
        else:
            print("Accept marks only between 0 and 100")
S=Student(95)
S.get_marks()
S.set_marks(100)
# Out:
# 95

# %% [markdown]
# # 3

# %%
class Employee:
    def __init__(self,salary):
        self.__salary=salary
    def get_salary(self):
        return self.__salary
    def set_salary(self,new_salary):
        min_salary=self.__salary*0.9
        if new_salary>=min_salary:
            self.__salary=new_salary
            print("Salary updated")
        else:
            print("Rejected")
Emp=Employee(60000)
Emp.set_salary(42000)
print(Emp.get_salary())
# Out:
# Rejected
# 60000

# %% [markdown]
# # 4

# %%
class Mobile:
    def __init__(self,price):
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self,price):
        if price>0:
            return self.__price
        else:
            print("Invalid")
Mob=Mobile(60000)
Mob.get_price()
Mob.set_price(2000)
print(Mob.get_price())
# Out:
# 60000

# %% [markdown]
# # 5

# %%
class Person:
    def __init__(self,age):
        self.__age=age
    def get_age(self):
        return self.__age
    def set_age(self,age):
        if age>0:
            if age>=0 and age<=120:
                self.__age=age
        else:
            print("Invalid")
P=Person(22)
P.set_age(30)
print(P.get_age())
# Out:
# 30

# %% [markdown]
# # 6

# %%
class Product:
    def __init__(self,price,stock):
        self.__price=price
        self.__stock=stock
    def get_price(self):
        return self.__price
    def get_stock(self):
        return self.__stock
    def update_price(self,new_price):
        if new_price>0:
            self.__price=new_price
        else:
            print("Invalid price")
    def update_stock(self,quantity):
        if quantity>=0:
            self.__quantity=quantity
        else:
            print("Invalid quantity")
P1=Product(200,1)
print(P1.get_price())
print(P1.get_stock())
P1.update_price(250)
P1.update_stock(5)
print("updated price:",P1.get_price())
print("updated stock:",P1.get_stock())
# Out:
# 200
# 1
# updated price: 250
# updated stock: 1

# %% [markdown]
# # 7

# %%
from datetime import datetime
class Car:
    def __init__(self,model,year):
        self.__model=model
        self.__year=year
    def get_model(self):
        return self.__model
    def get_year(self):
        return self.__year
    def set_model(self):
        return self.__model
    def updated_year(self,new_year):
        current_year=datetime.now().year
        if new_year<=current_year:
            self.__year=new_year
        else:
            print("Year cannot be greater than current year") 
c1=Car("swift", 2022)
print("Model:", c1.get_model())
print("Year:",c1.get_year())
c1.updated_year(2027)
c1.updated_year(2026)
print("updated year:",c1.get_year())
# Out:
# Model: swift
# Year: 2022
# Year cannot be greater than current year
# updated year: 2026

# %% [markdown]
# # 8

# %%
class User:
    def __init__(self,password):
        self.__password=password
    def get_password(self):
        return self.__password
    def change_password(self,new_password):
        if len(new_password) >= 8:
            self.__password=new_password
        else:
            print("Invalid password")
U1=User("hari@0511")
print(U1.get_password())
U1.change_password("unnu@0511")
print("updated password:",U1.get_password())
# Out:
# hari@0511
# updated password: unnu@0511

# %% [markdown]
# # 9

# %%
class Rectangle:
    def __init__(self,length,width):
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def set_length(self,length):
        if length>0:
            self.__length=length
        else:
            print("Invalid length")
    def set_width(self,width):
        if width>0:
             self.__width=width
        else:
            print("Invalid width")
    def area(self):
        return self.__length*self.__width
R1=Rectangle(2,3)
print(R1.get_length())
print(R1.get_width())
print(R1.area())
R1.set_length(3)
R1.set_width(5)
print(R1.get_length())
print(R1.get_width())
print(R1.area())
# Out:
# 2
# 3
# 6
# 3
# 5
# 15

# %% [markdown]
# # 10

# %%
class Account:
    history=[]
    def __init__(self,balance):
        self.__balance=balance
    def get_balance(self):
        return self.__balance
    def deposite(self,amount):
        if amount>0:
            self.__balance+=amount
            Account.history.append(self.__balance)
        else:
            print("Invalid deposite")
    def withdraw(self,amount):
        if amount>0 and amount<=self.__balance:
            self.__balance-=amount
            Account.history.append(self.__balance)
        else:
            print("Insufficient balance")
A=Account(60000)
print(A.get_balance())
A.deposite(5000)
A.withdraw(3500)
print(A.get_balance())
print("history:",Account.history)
# Out:
# 60000
# 61500
# history: [65000, 61500]

# %% [markdown]
# # 11

# %%
class Temperature:
    def __init__(self,celsius):
        self.__celsius=celsius
    def get_celsius(self):
        return self.__celsius
    def set_celsius(self,celsius):
        self.__celsius=celsius
    def to_fahrenheit(self):
        fahrenheit=(self.__celsius*9/5)+32
        print(fahrenheit)
        
T=Temperature(20)
print(T.get_celsius())
T.set_celsius(80)
T.to_fahrenheit()
print(T.get_celsius())
# Out:
# 20
# 176.0
# 80

# %% [markdown]
# # 12

# %%
class Book:
    def __init__(self,price):
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self,price):
        if price>500:
            self.price = price-(price*10/100)
        else:
             self.__price=price
B=Book(300)
print(B.get_price())
B.set_price(500)
print(B.get_price())
# Out:
# 300
# 500

# %% [markdown]
# # 13

# %%
class Player:
    def __init__(self,score):
        self.__score=score
    def get_score(self):
        return self.__score
    def set_score(self,score):
        if score>0:
            self.__score=score
        else:
            print("Score cannot be negative")
P=Player(33)
print(P.get_score())
P.set_score(200)
print(P.get_score())
# Out:
# 33
# 200

# %% [markdown]
# # 14

# %%
class Laptop:
    def __init__(self,ram,storage):
        self.__ram=ram
        self.__storage=storage
    def get_ram(self):
        return self.__ram
    def get_storage(self):
        return self.__storage
    def set_ram(self,ram):
        if ram>0:
            self.__ram=ram
        else:
            print("ram should not be negative")
    def set_storage(self,storage):
        if storage>0:
             self.__storage=storage
        else:
            print("storage should not be negative")
   
L1=Laptop(12,220)
print(L1.get_ram())
print(L1.get_storage())
L1.set_ram(16)
L1.set_storage(512)
print(L1.get_ram())
print(L1.get_storage())
# Out:
# 12
# 220
# 16
# 512

# %% [markdown]
# # 15

# %%
class Employee:
    def __init__(self,id,salary):
        self.__id=id
        self.__salary=salary
    def get_id(self):
        return self.__id
    def get_salary(self):
        return self.__salary
Emp=Employee(426,40000)
print(Emp.get_id())
print(Emp.get_salary())
# Out:
# 426
# 40000

# %% [markdown]
# # Abstraction

# %% [markdown]
# # 16

# %%
from abc import ABC, abstractmethod
class Shape(ABC) :
    
    @abstractmethod
    def calculate_area(self):
        pass
    @abstractmethod
    def calculate_perimeter(self):
        pass
class Circle(Shape):
    def __init__(self,radius):
        self.radius=radius
    def calculate_area(self):
        return 3.14*self.radius*self.radius
        
    def calculate_perimeter(self):
        return 2*3.14*self.radius
class Rectangle(Shape):
    def __init__(self,length,breadth):
        self.length=length
        self.breadth=breadth
        
    def calculate_area(self):
        return self.length*self.breadth
        
    def calculate_perimeter(self):
        return 2*(self.length+self.breadth)
c=Circle(10)
print("Circle area:",c.calculate_area())
print("Circle perimeter:",c.calculate_perimeter())
r=Rectangle(20,5)
print("rectangle area:",r.calculate_area())
print("rectangle perimeter:",r.calculate_perimeter())
# Out:
# Circle area: 314.0
# Circle perimeter: 62.800000000000004
# rectangle area: 100
# rectangle perimeter: 50

# %%
from abc import ABC, abstractmethod
class Vehicle(ABC) :
    
    @abstractmethod
    def start(self):
        pass
    @abstractmethod
    def stop(self):
        pass
class Car(Vehicle):
    def start(self):
        print("Car starts with a key")
    def stop(self):
        print("Car stops with a brake")

class Bike(Vehicle):
    def start(self):
        print("Car starts with kick")
    def stop(self):
        print("Car stops with a brakes")
car=Car()
car.start()
car.stop()
bike=Bike()
bike.start()
bike.stop()
# Out:
# Car starts with a key
# Car stops with a brake
# Car starts with kick
# Car stops with a brakes

# %% [markdown]
# # 18

# %%
from abc import ABC, abstractmethod
class Payment(ABC) :
    
    @abstractmethod
    def process_payment(self,amount):
        pass

class CreditCardPayment(Payment):
    def process_payment(self,amount):
        print("processing credit card payment:{amount}")
    
class UPIPayment(Payment):
    def process_payment(self,amount):
        print("processing UPI payment:{amount}")
credit=CreditCardPayment()
credit.process_payment(5000)
upi=UPIPayment()
upi.process_payment(1500)
# Out:
# processing credit card payment:{amount}
# processing UPI payment:{amount}

# %% [markdown]
# # 19

# %%
from abc import ABC, abstractmethod
class Animals(ABC) :
    
    @abstractmethod
    def make_sound(self):
        pass

class Dog(Animals):
    def make_sound(self):
        print("Bhauuuu !")
    
class Cat(Animals): 
    def make_sound(self):
        print("Meowww !")
Dog=Dog()
Cat=Cat()
Dog.make_sound()
Cat.make_sound()
# Out:
# Bhauuuu !
# Meowww !

# %% [markdown]
# # 20

# %%
from abc import ABC, abstractmethod
class Report(ABC) :
    
    @abstractmethod
    def generate_report(self):
        pass

class PDFReport(Report):
    def generate_report(self):
        print("PDFReport is generated")
    
class ExcelReport(Report): 
    def generate_report(self):
        print("ExcelReport is generated")

p=PDFReport()
e=ExcelReport()
print(p.generate_report())
print(e.generate_report())
# Out:
# PDFReport is generated
# None
# ExcelReport is generated
# None

# %% [markdown]
# # 21

# %%
from abc import ABC, abstractmethod
class BankAccount(ABC) :
    
    @abstractmethod
    def calculate_interest(self):
        pass

class SavingsAccount(BankAccount):
    
    def __init__(self,balance):
        self.balance=balance
    def calculate_interest(self):
        return self.balance*0.05
    
class CurrentAccount(BankAccount):
    def __init__(self,balance):
        self.balance=balance
    def calculate_interest(self):
        return self.balance*0.02
savings=SavingsAccount(1500)
current=CurrentAccount(1500)
print("Savings Interest:",savings.calculate_interest())
print("Current Interest:",current.calculate_interest())
# Out:
# Savings Interest: 75.0
# Current Interest: 30.0

# %% [markdown]
# # 22

# %%
from abc import ABC, abstractmethod
class Device(ABC) :
    
    @abstractmethod
    def turn_on(self):
        pass
    def turn_off(self):
        pass
        
class TV(Device):
    def turn_on(self):
        print("TV is turned on")
    def turn_off(self):
        print("TV is turned off")
class Laptop(Device):
     def turn_on(self):
        print("Laptop is turned on")
     def turn_off(self):
        print("Laptop is turned off")
class Fan(Device):
     def turn_on(self):
        print("Fan is turned on")
     def turn_off(self):
        print("Fan is turned off")

t=TV()
t.turn_on()
t.turn_off()
L=Laptop()
L.turn_on()
L.turn_off()
f=Fan()
f.turn_on()
f.turn_off()
# Out:
# TV is turned on
# TV is turned off
# Laptop is turned on
# Laptop is turned off
# Fan is turned on
# Fan is turned off

# %% [markdown]
# # 23

# %%
from abc import ABC, abstractmethod
class Calculator(ABC) :
    
    @abstractmethod
    def compute(self,a,b):
        pass
   
class AddCalculator(Calculator):
    def compute(self,a,b):
        return a + b
class MultiplyCalculator(Calculator):
    def compute(self,a,b):
        return a * b
add = AddCalculator()
multiply = MultiplyCalculator()
print("Addition:", add.compute(20, 6))
print("Multiplication:", multiply.compute(20, 6))
# Out:
# Addition: 26
# Multiplication: 120

# %% [markdown]
# # 24

# %%
from abc import ABC, abstractmethod
class Employee(ABC) :
    
    @abstractmethod
    def calculate_bonus(self):
        pass
    
class Manager(Employee):
    def __init__(self,salary):
        self.salary=salary
        
    def calculate_bonus(self):
        return self.salary*0.20
        
class Developer(Employee):
    def __init__(self,salary):
        self.salary=salary 
        
    def calculate_bonus(self):
        return self.salary*0.15
        
class HR(Employee):
    def __init__(self,salary):
        self.salary=salary
        
    def calculate_bonus(self):
        return self.salary*0.10

manager=Manager(50000)
developer=Developer(50000)
hr=HR(50000)

print("Manager Bonus:",manager.calculate_bonus())
print("Developer Bonus:",developer.calculate_bonus())
print("HR Bonus:",hr.calculate_bonus())
# Out:
# Manager Bonus: 10000.0
# Developer Bonus: 7500.0
# HR Bonus: 5000.0

# %% [markdown]
# # 25

# %%
from abc import ABC, abstractmethod
class Shape3D(ABC):
    @abstractmethod
    def volume(self):
        pass

    @abstractmethod
    def surface_area(self):
        pass

class Cube(Shape3D):
    def __init__(self, side):
        self.side = side

    def volume(self):
        return self.side ** 3

    def surface_area(self):
        return 6 * (self.side ** 2)

class Sphere(Shape3D):
    def __init__(self, radius):
        self.radius = radius

    def volume(self):
        return (4/3) * 3.14 * (self.radius ** 3)

    def surface_area(self):
        return 4 * 3.14 * (self.radius ** 2)

class Cylinder(Shape3D):
    def __init__(self, radius, height):
        self.radius = radius
        self.height = height

    def volume(self):
        return 3.14 * (self.radius ** 2) * self.height

    def surface_area(self):
        return 2 * 3.14 * self.radius * (self.radius + self.height)

c = Cube(6)
s = Sphere(4)
cy = Cylinder(5, 8)

print("Cube Volume:", c.volume())
print("Cube Surface Area:", c.surface_area())
print("Sphere Volume:", s.volume())
print("Sphere Surface Area:", s.surface_area())
print("Cylinder Volume:", cy.volume())
print("Cylinder Surface Area:", cy.surface_area())
# Out:
# Cube Volume: 216
# Cube Surface Area: 216
# Sphere Volume: 267.94666666666666
# Sphere Surface Area: 200.96
# Cylinder Volume: 628.0
# Cylinder Surface Area: 408.20000000000005

# %% [markdown]
# # 26

# %%
from abc import ABC, abstractmethod
class Notification(ABC):

    @abstractmethod
    def send(self,message):
        pass

class EmailNotification(Notification):
    def send(self, message):
        print("Email:",message)

class SMSNotification(Notification):
    def send(self, message):
        print("SMS:",message)

    def query(self, sql):
        print("Executing MongoDB Query:", sql)

email = EmailNotification()
sms = SMSNotification()

email.send("Welcome to Python!")
sms.send("Your recharge is success")
# Out:
# Email: Welcome to Python!
# SMS: Your recharge is success

# %% [markdown]
# # 27

# %%
from abc import ABC, abstractmethod
class Database(ABC):

    @abstractmethod
    def connect(self):
        pass

    @abstractmethod
    def query(self, sql):
        pass


class MySQLDatabase(Database):
    def connect(self):
        print("Connected to MySQL Database")

    def query(self, sql):
        print("Executing MySQL Query:", sql)

class MongoDatabase(Database):

    def connect(self):
        print("Connected to MongoDB Database")

    def query(self, sql):
        print("Executing MongoDB Query:", sql)

mysql = MySQLDatabase()
mysql.connect()
mysql.query("SELECT * FROM students")

mongo = MongoDatabase()
mongo.connect()
mongo.query("db.students.find()")
# Out:
# Connected to MySQL Database
# Executing MySQL Query: SELECT * FROM students
# Connected to MongoDB Database
# Executing MongoDB Query: db.students.find()

# %% [markdown]
# # 28

# %%
from abc import ABC, abstractmethod
class GameCharacter(ABC):

    @abstractmethod
    def attack(self):
        pass
        
class Warrior(GameCharacter):
    def attack(self):
        print("Warrior attacks with a sword.")

class Archer(GameCharacter):
    def attack(self):
        print("Archer attacks with a bow and arrow.")

class Mage(GameCharacter):
    def attack(self):
        print("Mage attacks with magic spells.")



w = Warrior()
a = Archer()
m = Mage()

w.attack()
a.attack()
m.attack()
# Out:
# Warrior attacks with a sword.
# Archer attacks with a bow and arrow.
# Mage attacks with magic spells.

# %% [markdown]
# # 29

# %%
from abc import ABC, abstractmethod
class Transport(ABC):

    @abstractmethod
    def move(self):
        pass
    @abstractmethod
    def fuel_type(self):
        pass


class Car(Transport):
    def move(self):
        print("Car moves on roads")
    def fuel_type(self):
        print("Fuel Type: Petrol")

class Train(Transport):
    def move(self):
        print("Train moves on railway tracks")
    def fuel_type(self):
        print("Fuel Type: Electricity")

class Airplane(Transport):
    def move(self):
        print("Airplane flies in the sky")
    def fuel_type(self):
        print("Fuel Type: Aviation Fuel")



c = Car()
c.move()
c.fuel_type()

t = Train()
t.move()
t.fuel_type()

a = Airplane()
a.move()
a.fuel_type()
# Out:
# Car moves on roads
# Fuel Type: Petrol
# Train moves on railway tracks
# Fuel Type: Electricity
# Airplane flies in the sky
# Fuel Type: Aviation Fuel

# %% [markdown]
# # 30

# %%
from abc import ABC, abstractmethod
class FileHandler(ABC):

    @abstractmethod
    def read(self):
        pass

    @abstractmethod
    def write(self, data):
        pass

class TextFileHandler(FileHandler):

    def read(self):
        print("Reading data from a text file.")

    def write(self, data):
        print("Writing to text file:", data)

class CSVFileHandler(FileHandler):

    def read(self):
        print("Reading data from a CSV file.")

    def write(self, data):
        print("Writing to CSV file:", data)



text = TextFileHandler()
text.read()
text.write("Hello World")

csv = CSVFileHandler()
csv.read()
csv.write("Name,Age\nHaritha,22")
# Out:
# Reading data from a text file.
# Writing to text file: Hello World
# Reading data from a CSV file.
# Writing to CSV file: Name,Age
# Haritha,22
