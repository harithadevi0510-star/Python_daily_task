# %% [markdown]
# # Class and Object

# %% [markdown]
# # 1

# %%
class Student:
    def __init__(self, name, age):
        self.Name=name
        self.Age=age
    def display_details(self):
        print("name:", self.Name)
        print("age:", self.Age)
std1=Student("Hari",22)
std1.display_details()
std2=Student("Akshi",21)
std2.display_details()
# Out:
# name: Hari
# age: 22
# name: Akshi
# age: 21

# %% [markdown]
# # 2

# %%
class Car:
    def __init__(self, brand, model, year):
        self.Brand=brand
        self.Model=model
        self.Year=year
    def display_details(self):
        print("brand:", self.Brand)
        print("model:", self.Model)
        print("year:", self.Year)
C1=Car("Thar", "xuv300", 2026)
C1.display_details()
# Out:
# brand: Thar
# model: xuv300
# year: 2026

# %% [markdown]
# # 3

# %%
class Book:
    def __init__(self, title, author, price):
        self.Title=title
        self.Author=author
        self.Price=price
    def display_info(self):
        print("title:", self.Title)
        print("author:", self.Author)
        print("price:", self.Price)
B1=Book("life", "Neha", 200)
B1.display_info()
# Out:
# title: life
# author: Neha
# price: 200

# %% [markdown]
# # 4

# %%
class Employee:
    def __init__(self, emp_id, name, salary):
        self.emp_id=emp_id
        self.name=name
        self.salary=salary
    def display_details(self):
        print("emp_id:", self.emp_id)
        print("name:", self.name)
        print("salary:", self.salary)
emp1=Employee(418,"Hari",2000)
emp1.display_details()
emp2=Employee(426,"Akshi",2100)
emp2.display_details()
emp3=Employee(425,"Akshitha",2200)
emp3.display_details()
# Out:
# emp_id: 418
# name: Hari
# salary: 2000
# emp_id: 426
# name: Akshi
# salary: 2100
# emp_id: 425
# name: Akshitha
# salary: 2200

# %% [markdown]
# # 6

# %%
class Rectangle:
    def __init__(self, length, width):
        self.length=length
        self.width=width
    def cal_area(self):
        print("area:",self.length * self.width)
r=Rectangle(5,6)
r.cal_area()
# Out:
# area: 30

# %% [markdown]
# # 7

# %%
class Person:
    def __init__(self, name, city):
        self.name=name
        self.city=city
    def display_details(self):
        print("name:", self.name)
        print("city:", self.city)        
per1=Person("Haritha", "Warangal")
per1.display_details()
per1.city="Hyd"
per1.display_details()
# Out:
# name: Haritha
# city: Warangal
# name: Haritha
# city: Hyd

# %% [markdown]
# # 8

# %%
class Laptop:
    def __init__(self, brand, RAM , price):
        self.brand=brand
        self.RAM=RAM
        self.price=price
    def display_details(self):
        print("brand:", self.brand)
        print("RAM:", self.RAM)
        print("price:", self.price)
L1=Laptop("hp", "120GB", 50000)
L1.display_details()
L2=Laptop("Lenovo", "125GB",60000)
L2.display_details()
L3=Laptop("Apple", "315GB",90000)
L3.display_details()
# Out:
# brand: hp
# RAM: 120GB
# price: 50000
# brand: Lenovo
# RAM: 125GB
# price: 60000
# brand: Apple
# RAM: 315GB
# price: 90000

# %% [markdown]
# # Class Attributes

# %% [markdown]
# # 9

# %%
class Student:
    School_name = "City School"
    def __init__(self,name,class_name):
        self.name=name
        self.class_name=class_name
    def display_info(self):
        print(f"Student_name:{self.name}")
        print(f"Class_name:{self.class_name}")
        print(f"School_name:{Student.school_name}")
std1=Student("Haritha", 10)
std1.display_info()
print("-"*20)
std2=Student("Varshitha", 10)
std2.display_info()
# Out:
# Student_name:Haritha
# Class_name:10
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 11
#       9         print(f"School_name:{Student.school_name}")
#      10 std1=Student("Haritha", 10)
# ---> 11 std1.display_info()
#      12 print("-"*20)
#      13 std2=Student("Varshitha", 10)
#
# Cell In[5], line 9, in Student.display_info(self)
#       7 print(f"Student_name:{self.name}")
#       8 print(f"Class_name:{self.class_name}")
# ----> 9 print(f"School_name:{Student.school_name}")
#
# AttributeError: type object 'Student' has no attribute 'school_name'

# %%
class Laptop:
    def __init__(self, brand, RAM , price):
        self.brand=brand
        self.RAM=RAM
        self.price=price
    def display_details(self):
        print("brand:", self.brand)
        print("RAM:", self.RAM)
        print("price:", self.price)
L1=Laptop("hp", "120GB", 50000)
L1.display_details()
L2=Laptop("Lenovo", "125GB",60000)
L2.display_details()
L3=Laptop("Apple", "315GB",90000)
L3.display_details()

# %% [markdown]
# # 10

# %%
class Bank:
    Bank_name="SBI"
    def __init__(self, ac_holder, balance):
        self.ac_holder=ac_holder
        self.balance=balance
    def display_details(self):
        print(f"ac_holder:{self.ac_holder}")
        print(f"balance:{self.balance}")
        print(f"Bank:{Bank.Bank_name}")
    # class method
    @classmethod
    def change_bank_name(cls,name):
        cls.Bank_name=name
        print(f"Bank name {cls.Bank_name} updated successfully")
B1=Bank("Haritha",2000)
B1.display_details()
B1.change_bank_name("Union")
B1.display_details()
# Out:
# ac_holder:Haritha
# balance:2000
# Bank:SBI
# Bank name Union updated successfully
# ac_holder:Haritha
# balance:2000
# Bank:Union

# %% [markdown]
# # 11

# %%
class Counter:
    count=0
    def increment(self):
        Counter.count+=1
        print(Counter.count)
C1=Counter()
C1.increment()
C1.increment()
C1.increment()
# Out:
# 1
# 2
# 3

# %% [markdown]
# # 12

# %%
class Employee:
    company_name="ABC Crop"
    def __init__(self,name,emp_id):
        self.name=name
        self.emp_id=emp_id
    def display_details(self):
        print(f"Employee name:{self.name}")
        print(f"Employee emp_id:{self.emp_id}")
        print(f"Employee company name:{Employee.company_name}")
E1=Employee("Haritha","hari@0511")
E1.display_details()
E2=Employee("varshini","varsh1203")
E2.display_details()
# Out:
# Employee name:Haritha
# Employee emp_id:hari@0511
# Employee company name:ABC Crop
# Employee name:varshini
# Employee emp_id:varsh1203
# Employee company name:ABC Crop

# %% [markdown]
# # 13

# %%
class Circle:
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        pi=3.14
        area=pi*self.radius*self.radius
        print(f"The area of circle:{area}")
R1=Circle(10)
R1.area()
# Out:
# The area of circle:314.0

# %% [markdown]
# # 14

# %%
class MathUtils:
    def __init__(self,version):
        self.version=version
    def Math_details(self):
        print(f" version:{self.version}")
M1=MathUtils(1.0)
M1.Math_details()
# Out:
#  version:1.0

# %% [markdown]
# # 15

# %%
class Player:
    team_name="India"   #class attribute
    def __init__(self,name):
        self.name=name   #instance attribute
    def display_details(self):
        print(f"Player name:{self.name}")
        print(f"Player team_name:{self.team_name}")
C1=Player("Hardik")
C1.display_details()
C2=Player("Tilak")
C2.display_details()
# Out:
# Player name:Hardik
# Player team_name:India
# Player name:Tilak
# Player team_name:India

# %% [markdown]
# # Private Attributes

# %% [markdown]
# # 16

# %%
class BankAccount:
    def __init__(self,balance):
        self.__balance=balance
B=BankAccount(2234567)
B.self__balance()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 5
#       3         self.__balance=balance
#       4 B=BankAccount(2234567)
# ----> 5 B.self__balance()
#
# AttributeError: 'BankAccount' object has no attribute 'self__balance'

# %% [markdown]
# # 17

# %%
class Student:
    def __init__(self,marks):
        self.__marks=marks
    def get__marks(self):
        print(self.__marks)
S=Student([90,80,75])
S.get__marks()
# Out:
# [90, 80, 75]

# %% [markdown]
# # 18

# %%
class Employee:
    def __init__(self,salary):
        self.__salary=salary
    def get__salary(self):
        print(self.__salary)
Emp=Employee(65000)
Emp.get__salary()
# Out:
# 65000

# %% [markdown]
# # 19

# %%
class Product:
    def __init__(self,price):
        self.__price=price
P=Product("Vimgel")
P.self__price()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 5
#       3         self.__price=price
#       4 P=Product("Vimgel")
# ----> 5 P.self__price()
#
# AttributeError: 'Product' object has no attribute 'self__price'

# %% [markdown]
# # 20

# %%
class User:
    def __init__(self,password):
        self.__password=password
    def get__password(self):
        print(self.__password)
U=User("hari05")
U.get__password()
# Out:
# hari05

# %% [markdown]
# # 21

# %%
class Car:
    def __init__(self,model,year):
        self.__model=model
        self.__year=year
    def get__model(self):
        print(self.__model)
    def get__year(self):
        print(self.__year)
C=Car("BMW",2025)
C.get__model()
C.get__year()
# Out:
# BMW
# 2025

# %% [markdown]
# # 22

# %%
class Account:
    def __init__(self,account_number):
        self.__account_number=account_number
    def get__account_number(self):
        print(self.__account_number)
A=Account(234587655)
A.get__account_number()
# Out:
# 234587655

# %% [markdown]
# # Getter and Setter

# %% [markdown]
# # 23

# %%
class Student:
    def __init__(self,marks):
        self.__marks=marks
    def get__marks(self):
        return self.__marks
    def set__marks(self,marks):
        self.__marks=marks
S=Student(90)
print(S.get__marks())
S.set__marks(100)
print(S.get__marks())
# Out:
# 90
# 100

# %% [markdown]
# # 24

# %%
class BankAccount:
    def __init__(self,balance):
        self.__balance=balance
    def get__balance(self):
        return self.__balance
    def set__balance(self,balance):
        self.__balance=balance
B=BankAccount(20000)
print(B.get__balance())
B.set__balance(25000)
print(B.get__balance())
# Out:
# 20000
# 25000

# %% [markdown]
# # 25

# %%
class Employee:
    def __init__(self,salary):
        self.__salary=salary
    def get_salary(self):
        return self.__salary
    def set_salary(self,salary):
        if salary>=5000:
            self.__salary=salary
        else:
            print("Salary should not be below 5000")
Emp=Employee(2000)
Emp.set_salary(20000)
print(Emp.get_salary())
Emp.set_salary(3000)
# Out:
# 20000
# Salary should not be below 5000

# %% [markdown]
# # 26

# %%
class Temperature:
    def __init__(self,celsius=0):
        self.__celsius=celsius
    def get_celsius(self):
        return self.__celsius
    def set_celsius(self,celsius):
        self.__celsius=celsius
    def to_fahrenheit(self):
        return (self.__celsius*9/5)+32
t=Temperature()
t.set_celsius(25)
print(t.get_celsius())
print(t.to_fahrenheit())
# Out:
# 25
# 77.0

# %% [markdown]
# # 27

# %%
class Person:
    def __init__(self,age):
        self.__age=age
    def get_age(self):
        return self.__age
    def set_age(self,age):
        if age>0 and age<=120:
            self.__age=age
        else:
            print("Age Invalid")
p=Person(25)
p.set_age(40)
print(p.get_age())
p.set_age(150)
# Out:
# 40
# Age Invalid

# %% [markdown]
# # 28

# %%
class Product:
    def __init__(self,price):
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self,price):
        self.__price=price
    def discount(self,discount):
        self.__price=self.__price-(self.__price*discount/100)
p=Product("comfort")
p.set_price(2000)
p.discount(15)
print(p.get_price())
# Out:
# 1700.0

# %% [markdown]
# # 29

# %%
class Mobile:
    def __init__(self,price=0):
        self.__price=price
    def get_price(self):
        return self.__price
    def set_price(self,price):
        self.__price=price
        print("price changed successfully")
m=Mobile()
m.set_price(25000)
print(m.get_price())
# Out:
# price changed successfully
# 25000

# %% [markdown]
# # 30

# %%
class Rectangle:
    def __init__(self,length=0,width=0):
        self.__length=length
        self.__width=width
    def get_length(self):
        return self.__length
    def get_width(self):
        return self.__width
    def set_length(self,length):
        self.__length=length
    def set_width(self,width):
        self.__width=width   
    def area(self):
        return self.__length*self.__width
R1=Rectangle(10,20)
R1.set_length(10)
R1.set_width(20)
print(R1.get_length())
print(R1.get_width())
print(R1.area())
# Out:
# 10
# 20
# 200

# %%
class
