# %% [markdown]
# # String Slicing Questions

# %% [markdown]
# # 1

# %%
name=input("Enter the name:")
print(name[:6])
# Out:
# Enter the name: harithadevi
# harith

# %% [markdown]
# # 2

# %%
name="haritha devi"
print(name[-4:])
# Out:
# devi

# %% [markdown]
# # 3

# %%
name="haritha devi"
print(name[2:9])
# Out:
# ritha d

# %% [markdown]
# # 4

# %%
name="haritha devi"
print(name[1::2])
# Out:
# aih ei

# %% [markdown]
# # 5

# %%
name=input("Enter the name: ")
first = name.index(" ")
last = name.rindex(" ")
print("First name:", name[:first])
print("Last name:", name[last+1:])
# Out:
# Enter the name:  Sumit Kumar Sharma
# First name: Sumit
# Last name: Sharma

# %% [markdown]
# # Case Conversion Questions

# %% [markdown]
# # 6

# %%
name=input("Enter the name: ")
print(name.upper())
print(name.lower())
print(name.title())
print(name.capitalize())
# Out:
# Enter the name:  haritha devi
# HARITHA DEVI
# haritha devi
# Haritha Devi
# Haritha devi

# %% [markdown]
# # 7

# %%
s=input("Enter the sentence: ")
print(s.title())
print(s)
# Out:
# Enter the sentence:  my name is chikki bakki
# My Name Is Chikki Bakki
# my name is chikki bakki

# %% [markdown]
# # 8

# %%
name="hello World"
print(name.isupper())
print(name.islower())
print(name)
# Out:
# False
# False
# hello World

# %% [markdown]
# # String Check Methods Questions

# %% [markdown]
# # 9

# %%
name=input("Enter the name: ")
print(name.isalpha())
# Out:
# Enter the name:  haritha
# True

# %%
name=input("Enter the name: ")
print(name.isalpha())
# Out:
# Enter the name:  haritha05
# False

# %%
name=input("Enter the name: ")
print(name.isalpha())
# Out:
# Enter the name:  hari@
# False

# %% [markdown]
# # 10

# %%
name=input("Enter the name: ")
print(name.isdigit())
# Out:
# Enter the name:  12345
# True

# %%
name=input("Enter the name: ")
print(name.isdigit())
# Out:
# Enter the name:  1234@4
# False

# %%
name=input("Enter the name: ")
print(name.isdigit())
# Out:
# Enter the name:  ha@123
# False

# %% [markdown]
# # 11

# %%
name="harithadevi1"
print(name.isalnum())
# Out:
# True

# %%
name="harithadevi"
print(name.isalnum())
# Out:
# True

# %%
name="1234"
print(name.isalnum())
# Out:
# True

# %% [markdown]
# # 12

# %%
name="harithadevi"
print(name.islower())
# Out:
# True

# %% [markdown]
# # 13

# %%
p=input()
if p.isalnum and len(p) > 8:
    print("Valid Password")
else:
    print("Invalid Password")
# Out:
#  hari05111
# Valid Password

# %%
p=input()
if p.isalnum and len(p) >= 8:
    print("Valid Password")
else:
    print("Invalid Password")
# Out:
#  hari0510
# Valid Password

# %% [markdown]
# # find() and index()

# %%
s="my name is haritha"
ch=input()
print(s.find(ch))
# Out:
#  y
# 1

# %% [markdown]
# # 15

# %%
s="my name is haritha"
w=input()
if s.find(w) != -1:
    print("Word exists")
else:
    print("-1")
# Out:
#  haritha
# Word exists

# %%
s="my name is haritha"
w=input()
if s.find(w) != -1:
    print("Word exists")
else:
    print("-1")
# Out:
#  aksh
# -1

# %%
s=input("Enter the s: ")
word=input("Enter the word: ")
if s.find(word) != -1:
    print("Word exists")
else:
    print("-1")
# Out:
# Enter the s:  i love my mom
# Enter the word:  dad
# -1

# %% [markdown]
# # 16

# %%
s=input("Enter the s: ")
print(s.index("Python"))
# Out:
# Enter the s:  Python is easy
# 0

# %% [markdown]
# # 17

# %%
name="harithadevi"
ch="c"
print(name.find(ch))
print(name.index(ch))
# Out:
# -1
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[46], line 4
#       2 ch="c"
#       3 print(name.find(ch))
# ----> 4 print(name.index(ch))
#
# ValueError: substring not found

# %% [markdown]
# # 18

# %%
name="sandhyarani dubbaka"
print(name.upper())
print(name.find(" "))
parts=name.split()
print(parts)
first=parts[0]
print("first name is:",first)
second=parts[1]
print("second name is:",second)
# Out:
# SANDHYARANI DUBBAKA
# 11
# ['sandhyarani', 'dubbaka']
# first name is: sandhyarani
# second name is: dubbaka

# %% [markdown]
# # 19

# %%
m="7386918086"
print(m.isdigit())
print(len(m))
# Out:
# True
# 10

# %% [markdown]
# # 20

# %%
s=input("Enter the value: ")
a=print(s[::-1])
print(s.title())
if s == a:
    print("Palindrome")
else:
    print("Not a Palindrome")
# Out:
# Enter the value:  radar
# radar
# Radar
# Not a Palindrome
