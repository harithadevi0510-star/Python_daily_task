# %% [markdown]
# # String Methods and Lists

# %% [markdown]
# # 1

# %%
s=input("Enter the s: ")
print(s.replace(" ","_"))
# Out:
# Enter the s:  my name is haritha
# my_name_is_haritha

# %% [markdown]
# # 2

# %%
s=" Haritha "
print(s.strip())
print(s.rstrip())
print(s.lstrip())
# Out:
# Haritha
#  Haritha
# Haritha

# %% [markdown]
# # 3

# %%
s=input("Enter the s: ")
if s.startswith("Hello"):
    print("Yes")
else:
    print("No")
# Out:
# Enter the s:  Hello world
# Yes

# %%
s=input("Enter the s: ")
if s.startswith("Hello"):
    print("Yes")
else:
    print("No")
# Out:
# Enter the s:  hello world
# No

# %%
s=input("Enter the s: ")
print(s.startswith("Hello"))
# Out:
# Enter the s:  Hello world
# True

# %% [markdown]
# # 4

# %%
s=input("Enter the s: ")
if s.endswith(".com"):
    print("Yes")
else:
    print("No")
# Out:
# Enter the s:  haritha@gmail.com
# Yes

# %%
s=input("Enter the s: ")
print(s.endswith(".com"))
# Out:
# Enter the s:  hari@gmail.com
# True

# %% [markdown]
# # 5

# %%
s = "apple, banana, mango"
print(s.split(", "))
# Out:
# ['apple', 'banana', 'mango']

# %%
s="apple,banana,mango"
print(s.split(","))
# Out:
# ['apple', 'banana', 'mango']

# %% [markdown]
# # 6

# %%
list1=["apple","banana","grapes","guava","papaya"]
print(" ".join(list1))
# Out:
# apple banana grapes guava papaya

# %% [markdown]
# # 7

# %%
list1 = ["Python", "is", "awesome"]
list2 = [word.strip() for word in list1]
print(list2)
print(" ".join(list2))
# Out:
# ['Python', 'is', 'awesome']
# Python is awesome

# %% [markdown]
# # 8

# %%
name="Haritha Devi Dubbaka"
words = name.split()
print(words[0])
print(words[2])
# Out:
# Haritha
# Dubbaka

# %% [markdown]
# # 9

# %%
s=input("Enter the s: ")
words = s.split()
count = len(words)
print("Total number of words:", count)
# Out:
# Enter the s:  my name is haritha
# Total number of words: 4

# %% [markdown]
# # 10

# %%
email = input("Enter your email: ")
if email.endswith("@gmail.com"):
    print("This is a gmail address")
else:
    print("This is a gmail address")
# Out:
# Enter your email:  harithadevi0510@gmail.com
# This is a gmail address

# %% [markdown]
# # 11

# %%
text = "Hello World Python"
new_text = text.replace("World", "Everyone")
words = new_text.split()
print("Updated String", new_text)
print("List of Words:", words)
# Out:
# Updated String Hello Everyone Python
# List of Words: ['Hello', 'Everyone', 'Python']

# %% [markdown]
# # 12

# %%
cities = []
for i in range(5):
    city = input("Enter city name: ")
    cities.append(city)
result = "\n".join(cities)
print("Cities are:")
print(result)
# Out:
# Enter city name:  warangal
# Enter city name:  karimnagar
# Enter city name:  hyderabad
# Enter city name:  hanumakonda
# Enter city name:  mulkanoor
# Cities are:
# warangal
# karimnagar
# hyderabad
# hanumakonda
# mulkanoor

# %% [markdown]
# # 13

# %%
word=input("Enter the word: ")
print(word.title())
# Out:
# Enter the word:  hello world
# Hello World

# %% [markdown]
# # 14

# %%
s = "she is good girl"
print(s.replace("good", "bad"))
print(s.split(","))
print(s.join(" "))
# Out:
# she is bad girl
# ['she is good girl']

# %% [markdown]
# # 15

# %%
list1 = ["10","20","30","40"]
print("-".join(list))
# Out:
# 10-20-30-40

# %%
s=input("Enter the s: ")
print(s.split(","))
for vowel in "aeiouAEIOU":
    s = s.replace(vowel, "")
print(s)
print(" ".join(s.split()))
# Out:
# Enter the s:  my name is hari
# ['my name is hari']
# my nm s hr
# my nm s hr

# %% [markdown]
# # 17

# %%
s=input("Enter the s: ")
s = s.replace(" ", "-")
words = s.split("-")
for word in words:
    if len(word) > 4:
        print(word)
# Out:
# Enter the s:  my name is haritha
# haritha

# %% [markdown]
# # 18

# %%
students = ["Hari", "Akshi", "Varshi", "Sweety"]
result = ",".join(students)
result = result.replace("Hari", "Neha")
print(result)
# Out:
# Neha,Akshi,Varshi,Sweety

# %% [markdown]
# # 19

# %%
paragraph = input("Enter a paragraph: ")
sentences = paragraph.split(".")
for i in range(len(sentences)):
    sentences[i] = sentences[i].strip()
print("-"+"\n- ".join(sentences[:-1]))
# Out:
# Enter a paragraph:  python is easy.it is powerful.everyone can learn it.
# -python is easy
# - it is powerful
# - everyone can learn it

# %% [markdown]
# # 20

# %%
s = input("Enter a string: ")
s = s.strip()
s = s.replace("-", " ")
words = s.split()
result = " ".join(words)
print(result)
